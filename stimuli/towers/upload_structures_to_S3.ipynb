# %% [markdown]
# # Upload tower stimuli to s3

# %%
#Which experiment? bucket_name is the name of the experiment and will be name of the databases both on mongoDB and S3

bucket_name = 'lax-structures-bridge-all' #containment
stim_version = 'lax-structures-bridge-all'

ext = 'json'

# composites (includes ambiguous stims twice)
# bucket_name = 'lax-tower-4-block-unique-silhouettes-composites-json' #containment
# stim_version = 'tower_4_block_unique_silhouettes_composites_json'

# %%
import os
from glob import glob
import boto3
import botocore
from IPython.display import clear_output
import json
import pandas as pd
from PIL import Image

# %%
def list_files(paths, ext=ext):
    """Pass list of folders if there are stimuli in multiple folders. 
    Make sure that the containing folder is informative, as the rest of the path is ignored in naming. 
    Also returns filenames as uploaded to S3"""
    if type(paths) is not list:
        paths = [paths]
    results = []
    names = []
    for path in paths:
        results += [y for x in os.walk(path) for y in glob(os.path.join(x[0], '*.%s' % ext))]
        names += [os.path.split(y)[1] for x in os.walk(path) for y in glob(os.path.join(x[0], '*.%s' % ext))]
    return results,names

# %%
## helper to speed things up by not uploading images if they already exist, can be overriden 
def check_exists(s3, bucket_name, stim_name):
    try:
        s3.Object(bucket_name,stim_name).load()    
        return True
    except botocore.exceptions.ClientError as e:    
        if (e.response['Error']['Code'] == "404"):
            print('The object does not exist.')
            return False
        else:
            print('Something else has gone wrong with {}'.format(stim_name))

# %% [markdown]
# Pass list of folders if there are stimuli in multiple folders. Make sure that the containing folder is informative, as the rest of the path is ignored in naming.

# %%
## set up paths, etc.
# paths_to_stim = ['./example'] ## provide a list of full paths here.
paths_to_stim = [
    
    # tower silhouettes
    "./" + stim_version,
    
]

# paths_to_stim = glob.glob()
full_stim_paths, filenames = [x for x in list_files(paths_to_stim) if x !='.DS_Store'] #generate filenames and stimpaths
print('We have {} stimuli to upload.'.format(len(full_stim_paths)))
# Out:
# We have 250 stimuli to upload.

# %% [markdown]
# Upload to S3. This expects the `.aws/credentials` file in your home directory.

# %%
reallyRun = True
if reallyRun:

    ## establish connection to s3 
    s3 = boto3.resource('s3')

    ## create a bucket with the appropriate bucket name
    try: 
        b = s3.create_bucket(Bucket=bucket_name) 
        print('Created new bucket.')
#     except NoCredentialsError:
#         print("Credential missing") #.aws/credentials should be in home folder, not in repo folder
    except:
        b = s3.Bucket(bucket_name)
        print('Bucket already exists.')

    ## do we want to overwrite files on s3?
    overwrite = True
    
    ## set bucket and objects to public
    b.Acl().put(ACL='public-read') ## sets bucket to public

    ## now let's loop through stim paths and actually upload to s3 (woot!)
    for i,path_to_file in enumerate(full_stim_paths):        # use sorted(full_stim_paths) when not using photodraw32
        stim_name = filenames[i]
        if ((check_exists(s3, bucket_name, stim_name)==False) | (overwrite==True)):
            print('Now uploading {} as {} | {} of {}'.format(os.path.split(path_to_file)[-1],stim_name,(i+1),len(full_stim_paths)))
            s3.Object(bucket_name,stim_name).put(Body=open(path_to_file,'rb')) ## upload stimuli
            s3.Object(bucket_name,stim_name).Acl().put(ACL='public-read') ## set access controls
        else: 
            print('Skipping {} | {} of {} because it already exists.'.format(os.path.split(path_to_file)[-1],(i+1),len(full_stim_paths)))
        clear_output(wait=True)
print('Done!')
# Out:
# Done!

# %%
for my_bucket_object in b.objects.all():
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='df_castle.csv')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-000-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-001-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-002-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-003-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-004-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-005-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-006-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-007-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-008-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-009-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-010-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-011-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-012-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-013-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-014-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-015-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-016-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-017-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-018-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-019-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-020-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-021-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-022-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-023-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-024-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-025-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-026-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-027-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-028-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-029-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-030-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-031-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-032-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-033-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-034-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-035-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-036-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-037-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-038-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-039-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-040-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-041-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-042-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-043-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-044-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-045-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-046-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-047-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-048-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-049-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-050-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-051-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-052-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-053-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-054-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-055-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-056-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-057-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-058-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-059-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-060-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-061-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-062-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-063-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-064-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-065-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-066-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-067-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-068-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-069-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-070-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-071-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-072-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-073-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-074-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-075-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-076-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-077-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-078-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-079-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-080-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-081-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-082-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-083-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-084-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-085-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-086-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-087-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-088-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-089-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-090-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-091-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-092-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-093-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-094-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-095-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-096-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-097-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-098-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-099-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-100-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-101-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-102-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-103-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-104-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-105-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-106-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-107-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-108-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-109-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-110-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-111-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-112-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-113-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-114-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-115-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-116-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-117-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-118-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-119-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-120-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-121-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-122-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-123-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-124-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-125-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-126-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-127-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-128-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-129-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-130-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-131-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-132-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-133-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-134-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-135-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-136-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-137-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-138-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-139-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-140-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-141-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-142-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-143-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-144-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-145-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-146-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-147-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-148-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-149-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-150-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-151-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-152-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-153-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-154-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-155-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-156-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-157-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-158-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-159-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-160-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-161-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-162-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-163-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-164-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-165-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-166-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-167-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-168-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-169-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-170-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-171-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-172-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-173-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-174-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-175-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-176-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-177-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-178-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-179-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-180-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-181-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-182-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-183-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-184-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-185-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-186-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-187-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-188-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-189-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-190-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-191-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-192-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-193-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-194-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-195-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-196-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-197-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-198-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-199-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-200-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-201-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-202-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-203-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-204-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-205-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-206-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-207-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-208-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-209-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-210-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-211-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-212-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-213-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-214-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-215-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-216-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-217-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-218-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-219-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-220-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-221-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-222-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-223-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-224-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-225-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-226-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-227-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-228-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-229-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-230-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-231-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-232-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-233-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-234-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-235-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-236-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-237-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-238-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-239-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-240-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-241-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-242-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-243-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-244-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-245-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-246-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-247-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-248-all.png')
# s3.ObjectSummary(bucket_name='lax-structures-castle-all', key='lax-structures-castle-249-all.png')

# %%
### add burn-in trials

# %%
### add catch trials
