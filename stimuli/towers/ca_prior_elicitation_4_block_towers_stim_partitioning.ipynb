# %%
from __future__ import division

import numpy as np
import os, sys
from PIL import Image
import pandas as pd
import json
import pickle

from matplotlib import pylab, mlab, pyplot
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.path import Path
import matplotlib.patches as patches
# %matplotlib inline

from IPython.core.pylabtools import figsize, getfigs

import seaborn as sns
from sklearn.model_selection import StratifiedKFold

import random

from scipy.stats import norm
from IPython.display import clear_output

import copy
import importlib


### Add Paths

## root paths
curr_dir = os.getcwd()
proj_dir = os.path.abspath(os.path.join(curr_dir,'..')) ## u\e relative paths

## add helpers to python path
import sys
if os.path.join(proj_dir, 'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir, 'stimuli'))

## import utils from git submodule
## custom helper modules
sys.path.append("./block_utils/")
import blockworld_utils as utils
import domino_settings as dominoes
# Out:
# /Users/will/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# setup
block_dims = dominoes.block_dims
block_colors = dominoes.block_colors
world_width = dominoes.world_width
world_height = dominoes.world_height
world_center = dominoes.world_center
black = ['#000000','#000000'] # used to display silhouettes
grey = ['#333333','#333333']

# %%
silhouette_superset = pd.read_pickle("./tower_4_block_unique_silhouettes/tower_4_block_unique_silhouettes.pkl")

# %% [markdown]
# Goal:
# 10 annotations total of each stim.
# Each participant should annotate a small number of towers (say less than 40).
# We should be able to check if different contexts change the annotations.
#
#
# Partition towers into 5 sets of 26 with roughly equal numbers of tall/ wide/ neither.
# Collect annotations from 5 ppts for each set.
# Find 2 such partitions.

# %%
groups = silhouette_superset[['tower_number_str','group']]
groups['group'].value_counts()
# Out:
# neither    94
# tall       18
# wide       18
# Name: group, dtype: int64

# %% [markdown]
# We have 18 wide and 18 tall towers.
# So each set should have 3 or 4 wides and 3 or 4 tall.

# %%
# neither = list(groups.loc[groups['group'] == 'neither','tower_number_str'])
# wide = list(groups.loc[groups['group'] == 'wide','tower_number_str'])
# tall = list(groups.loc[groups['group'] == 'tall','tower_number_str'])

# %%
n_families = 2
n_splits = 10
X = silhouette_superset['tower_number_str']
y = silhouette_superset['group']

for i in range(0, n_families):
    
    # set up partitioning
    skf = StratifiedKFold(n_splits=n_splits, 
                          random_state=i, 
                          shuffle=True) # tie random state to group num
    
    # apply partitioning and save to df
    for split_num, (train_index, test_index) in enumerate(skf.split(X, y)):
        silhouette_superset.loc[test_index,'family_'+str(i)] = split_num
#         print(groups.loc[test_index])

# silhouette_superset

# %%
# verify
if False:
    family = 1
    split = 0

    tower_worlds = [utils.worldify(w,
                                   block_dims = block_dims, 
                                   block_colors = block_colors)\
                        for w in silhouette_superset.groupby('family_'+str(family)).get_group(split)['stim']]

    for i, w in enumerate(tower_worlds):
        fig = utils.draw_tower(w)
        print(silhouette_superset.groupby('family_'+str(family)).get_group(split).reset_index(split).loc[i,'group'])

# %% [markdown]
# ## To run multiple versions, upload the same metadate to separate collections, and update stimColName in configs accordingly

# %%
experiment_name = 'ca_prior_elicitation_4_block_unique_silhouettes_procedural'
# experiment_name = 'ca_prior_elicitation_4_block_unique_silhouettes_categorization'
versionInd = 0

# %%
# connect to mongo

import pymongo as pm

# set vars 
auth = pd.read_csv('../../auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'cogtoolslab.org' ## experiment server ip address

conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
db = conn['stimuli']
coll = db[experiment_name]

# %%
# convert to lists of stimulus names

metadata = []

for f in range(0, n_families):
    for s in range(0,n_splits):
        stim_numbers = list(silhouette_superset.groupby('family_'+str(f)).get_group(s)['tower_number_str'])
#         print(stim_numbers)
        metadata.append(
            {
                'partitionFamily': f,
                'splitNumber': s,
                'stimNumbers': stim_numbers,
                'ntrials': len(stim_numbers),
                'stimGroups': {n: silhouette_superset.groupby('family_'+str(f)).get_group(s).reset_index().loc[i,'group'] for i, n in enumerate(stim_numbers)},
                'numGames': 0,
                'games': [],
                'experimentType': 'prior_elicitation',
                'experimentName': experiment_name,
                's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
                'versionInd': versionInd
            })

# %%
# Clear metadata collection

really_run = False;

if really_run:
    db.drop_collection(experiment_name)

# %%
## now, iterate through each version and insert into mongo
## loop through list of records and insert each into collection
reallyRun = False
if reallyRun:
    for (i,j) in enumerate(metadata):        
        coll.insert_one(j)
        print('Inserted version {} of stimDict.'.format(j['versionInd']))
        clear_output(wait=True)

else:
    print('Did not insert any new data.')
# Out:
# Did not insert any new data.

# %%
list(coll.find())
# Out:
# [{'_id': ObjectId('611bfd71767fe421dbdca4ac'),
#   'partitionFamily': 0,
#   'splitNumber': 0,
#   'stimNumbers': ['000',
#    '011',
#    '025',
#    '029',
#    '034',
#    '041',
#    '049',
#    '060',
#    '065',
#    '068',
#    '081',
#    '100',
#    '113'],
#   'ntrials': 13,
#   'stimGroups': {'000': 'neither',
#    '011': 'wide',
#    '025': 'wide',
#    '029': 'neither',
#    '034': 'neither',
#    '041': 'neither',
#    '049': 'neither',
#    '060': 'neither',
#    '065': 'neither',
#    '068': 'neither',
#    '081': 'neither',
#    '100': 'tall',
#    '113': 'neither'},
#   'numGames': 6,
#   'games': ['4636-ee3023be-6db3-47a7-ace2-6107dfd7ca29',
#    '0888-24a4244a-6fd2-46d8-b8d1-ad1cbe116ccd',
#    '9052-4a613e87-dd33-445c-98bb-19af91a6f1bd',
#    '5486-c491d5b0-7311-473e-ac05-9893b3abf381',
#    '5989-fe1433c8-7f3b-4a49-8613-d2421a22a335',
#    '0147-b0891954-08ff-46d8-81eb-b8feded612ea'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4ad'),
#   'partitionFamily': 0,
#   'splitNumber': 1,
#   'stimNumbers': ['007',
#    '009',
#    '019',
#    '023',
#    '053',
#    '061',
#    '062',
#    '072',
#    '076',
#    '084',
#    '086',
#    '106',
#    '115'],
#   'ntrials': 13,
#   'stimGroups': {'007': 'neither',
#    '009': 'neither',
#    '019': 'wide',
#    '023': 'wide',
#    '053': 'neither',
#    '061': 'neither',
#    '062': 'neither',
#    '072': 'neither',
#    '076': 'neither',
#    '084': 'neither',
#    '086': 'neither',
#    '106': 'neither',
#    '115': 'tall'},
#   'numGames': 5,
#   'games': ['1489-6cf0ecef-99d0-4ccb-b3fc-3e741663f960',
#    '8685-03ca5fcc-9d70-4091-9936-3896c804a8c1',
#    '2995-64d90112-592d-4a8b-bbd1-a8d3d74ab195',
#    '8685-70a79fa8-2fe3-4b92-82e2-c7bf07e21eca',
#    '1207-76e55728-fbd4-4dda-8713-5f6b62f487de'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4ae'),
#   'partitionFamily': 0,
#   'splitNumber': 2,
#   'stimNumbers': ['024',
#    '035',
#    '038',
#    '040',
#    '052',
#    '070',
#    '074',
#    '087',
#    '093',
#    '096',
#    '110',
#    '126',
#    '129'],
#   'ntrials': 13,
#   'stimGroups': {'024': 'wide',
#    '035': 'neither',
#    '038': 'neither',
#    '040': 'neither',
#    '052': 'neither',
#    '070': 'neither',
#    '074': 'neither',
#    '087': 'neither',
#    '093': 'neither',
#    '096': 'neither',
#    '110': 'neither',
#    '126': 'tall',
#    '129': 'tall'},
#   'numGames': 5,
#   'games': ['0590-e3b1f2aa-bc61-4f59-acf1-952248a65b8c',
#    '2597-f94b5609-a280-4a86-8227-4aacdb2e3cda',
#    '6165-8b606ef2-f5af-40b8-97b1-1c731c5bd0e7',
#    '0282-390aadd3-573c-4e40-baba-03c4a23d79be',
#    '4853-eadd19e0-8b8e-453f-b728-85a6af9a2848'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4af'),
#   'partitionFamily': 0,
#   'splitNumber': 3,
#   'stimNumbers': ['003',
#    '012',
#    '026',
#    '064',
#    '069',
#    '073',
#    '077',
#    '082',
#    '098',
#    '101',
#    '103',
#    '108',
#    '116'],
#   'ntrials': 13,
#   'stimGroups': {'003': 'neither',
#    '012': 'wide',
#    '026': 'neither',
#    '064': 'neither',
#    '069': 'neither',
#    '073': 'neither',
#    '077': 'neither',
#    '082': 'neither',
#    '098': 'neither',
#    '101': 'tall',
#    '103': 'neither',
#    '108': 'neither',
#    '116': 'tall'},
#   'numGames': 5,
#   'games': ['3885-08857f46-7106-4b80-98b8-8664a30c3371',
#    '5463-eaf1f652-1478-45f5-812c-8262e6162c3f',
#    '2014-7acd7925-8f3d-408e-85d6-a4bd888a6c1d',
#    '1158-5cebbab4-3477-4d3e-a3f6-63bab193a69e',
#    '4726-5f9ca9aa-32c5-49aa-8360-d83860084c40'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b0'),
#   'partitionFamily': 0,
#   'splitNumber': 4,
#   'stimNumbers': ['002',
#    '013',
#    '037',
#    '039',
#    '042',
#    '043',
#    '059',
#    '063',
#    '092',
#    '099',
#    '102',
#    '123',
#    '124'],
#   'ntrials': 13,
#   'stimGroups': {'002': 'wide',
#    '013': 'wide',
#    '037': 'neither',
#    '039': 'neither',
#    '042': 'neither',
#    '043': 'neither',
#    '059': 'neither',
#    '063': 'neither',
#    '092': 'tall',
#    '099': 'neither',
#    '102': 'tall',
#    '123': 'neither',
#    '124': 'neither'},
#   'numGames': 5,
#   'games': ['7482-6fb2c4c8-05dd-4da6-bfbf-4339753e03b6',
#    '3491-e8d166ce-6f01-4c14-9598-561c751d7a41',
#    '8880-86708957-c626-4432-ab66-bf1339c390dd',
#    '9752-50cd3768-4105-41ce-970d-a3d77be1a174',
#    '1715-9e32d7eb-d881-4f8d-95bc-65ba78b2bb88'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b1'),
#   'partitionFamily': 0,
#   'splitNumber': 5,
#   'stimNumbers': ['001',
#    '004',
#    '010',
#    '030',
#    '054',
#    '055',
#    '067',
#    '071',
#    '075',
#    '079',
#    '088',
#    '097',
#    '109'],
#   'ntrials': 13,
#   'stimGroups': {'001': 'wide',
#    '004': 'neither',
#    '010': 'wide',
#    '030': 'neither',
#    '054': 'neither',
#    '055': 'neither',
#    '067': 'neither',
#    '071': 'neither',
#    '075': 'neither',
#    '079': 'neither',
#    '088': 'neither',
#    '097': 'tall',
#    '109': 'tall'},
#   'numGames': 5,
#   'games': ['7764-bceefcff-f77b-4d76-b29c-876019d821dd',
#    '9625-4ce7e763-566c-4fb8-b9a8-b5ea1390f286',
#    '2236-9f84e6d7-96bb-4e94-8193-c1f87fa8dde5',
#    '5424-4f7c104e-6fd5-4468-ab5e-07668f1d8b9c',
#    '1501-7574fef9-bb43-4544-a827-cf7151d2e54f'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b2'),
#   'partitionFamily': 0,
#   'splitNumber': 6,
#   'stimNumbers': ['008',
#    '015',
#    '016',
#    '017',
#    '033',
#    '050',
#    '057',
#    '058',
#    '104',
#    '105',
#    '111',
#    '120',
#    '125'],
#   'ntrials': 13,
#   'stimGroups': {'008': 'wide',
#    '015': 'wide',
#    '016': 'neither',
#    '017': 'neither',
#    '033': 'neither',
#    '050': 'neither',
#    '057': 'neither',
#    '058': 'neither',
#    '104': 'neither',
#    '105': 'neither',
#    '111': 'tall',
#    '120': 'neither',
#    '125': 'tall'},
#   'numGames': 5,
#   'games': ['5172-3b8c352e-e806-44c6-8ffa-75a70b529dd0',
#    '2990-5e42050f-57d7-4a70-bba3-9a1fb1c32342',
#    '6618-6342a04a-b9cf-4d61-a96d-5f9d259542ce',
#    '4250-e599870d-f975-4cf8-a43b-f9e383be885a',
#    '8784-cf0f2889-d747-4c28-baa5-0c6d3c76d272'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b3'),
#   'partitionFamily': 0,
#   'splitNumber': 7,
#   'stimNumbers': ['005',
#    '020',
#    '036',
#    '044',
#    '078',
#    '080',
#    '085',
#    '091',
#    '095',
#    '107',
#    '114',
#    '118',
#    '119'],
#   'ntrials': 13,
#   'stimGroups': {'005': 'wide',
#    '020': 'wide',
#    '036': 'neither',
#    '044': 'neither',
#    '078': 'neither',
#    '080': 'neither',
#    '085': 'neither',
#    '091': 'neither',
#    '095': 'neither',
#    '107': 'neither',
#    '114': 'tall',
#    '118': 'tall',
#    '119': 'neither'},
#   'numGames': 5,
#   'games': ['5390-7409bacf-21a8-408d-9225-933fad434c5f',
#    '9760-4481917d-cbc5-4090-8f09-731ae359c225',
#    '3372-cc238a88-4c30-481c-8786-7d2d20cdf0d8',
#    '8451-19a7a57a-c794-430a-9e46-00269f5e6b43',
#    '5275-fc7ea476-3a58-43dd-8ab5-dfdbefbf281d'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b4'),
#   'partitionFamily': 0,
#   'splitNumber': 8,
#   'stimNumbers': ['014',
#    '018',
#    '021',
#    '027',
#    '028',
#    '045',
#    '046',
#    '051',
#    '056',
#    '083',
#    '112',
#    '122',
#    '127'],
#   'ntrials': 13,
#   'stimGroups': {'014': 'wide',
#    '018': 'wide',
#    '021': 'neither',
#    '027': 'neither',
#    '028': 'neither',
#    '045': 'neither',
#    '046': 'neither',
#    '051': 'neither',
#    '056': 'neither',
#    '083': 'neither',
#    '112': 'neither',
#    '122': 'tall',
#    '127': 'tall'},
#   'numGames': 5,
#   'games': ['3250-f415f026-0c38-4a60-86a9-6f7ce496689e',
#    '5093-7569bec0-a4a3-4f1f-ab17-cfad42d21fa4',
#    '0110-b1033429-c7a7-43fb-b411-ae54cd80e736',
#    '3001-1190aa85-abe7-4f2f-84a3-50feeeb71729',
#    '7063-757bb0af-95f3-42e5-b7d3-07e2ba819131'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b5'),
#   'partitionFamily': 0,
#   'splitNumber': 9,
#   'stimNumbers': ['006',
#    '022',
#    '031',
#    '032',
#    '047',
#    '048',
#    '066',
#    '089',
#    '090',
#    '094',
#    '117',
#    '121',
#    '128'],
#   'ntrials': 13,
#   'stimGroups': {'006': 'wide',
#    '022': 'wide',
#    '031': 'neither',
#    '032': 'neither',
#    '047': 'neither',
#    '048': 'neither',
#    '066': 'neither',
#    '089': 'neither',
#    '090': 'neither',
#    '094': 'neither',
#    '117': 'neither',
#    '121': 'tall',
#    '128': 'tall'},
#   'numGames': 5,
#   'games': ['0279-7cd774c9-a03a-47e3-898f-ea9d95c1fe14',
#    '0773-bfd38993-3211-4e26-91a9-c746b2828ace',
#    '0816-6f428560-c3d5-4558-b567-37aaaf67f6cd',
#    '0674-e85f1ce3-694f-4e67-9793-6f7c521e502d',
#    '3970-d05fffde-622f-4b19-b296-49214bebed94'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b6'),
#   'partitionFamily': 1,
#   'splitNumber': 0,
#   'stimNumbers': ['002',
#    '005',
#    '036',
#    '064',
#    '068',
#    '077',
#    '080',
#    '086',
#    '104',
#    '107',
#    '113',
#    '119',
#    '125'],
#   'ntrials': 13,
#   'stimGroups': {'002': 'wide',
#    '005': 'wide',
#    '036': 'neither',
#    '064': 'neither',
#    '068': 'neither',
#    '077': 'neither',
#    '080': 'neither',
#    '086': 'neither',
#    '104': 'neither',
#    '107': 'neither',
#    '113': 'neither',
#    '119': 'neither',
#    '125': 'tall'},
#   'numGames': 5,
#   'games': ['2228-9449b017-87a1-40ac-85d2-5ee70f41ce3f',
#    '9275-80d7ebaf-e722-4c95-ab90-6965694acaa7',
#    '3180-707ebd66-a4b3-40c7-9f10-9e3e50e00c85',
#    '1263-74e8a263-d3ec-49fe-b5fa-9a5f6103bec8',
#    '1272-caabf9a7-3570-4183-9b70-71dbdb1328d6'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b7'),
#   'partitionFamily': 1,
#   'splitNumber': 1,
#   'stimNumbers': ['012',
#    '019',
#    '035',
#    '040',
#    '057',
#    '078',
#    '088',
#    '091',
#    '095',
#    '096',
#    '108',
#    '115',
#    '123'],
#   'ntrials': 13,
#   'stimGroups': {'012': 'wide',
#    '019': 'wide',
#    '035': 'neither',
#    '040': 'neither',
#    '057': 'neither',
#    '078': 'neither',
#    '088': 'neither',
#    '091': 'neither',
#    '095': 'neither',
#    '096': 'neither',
#    '108': 'neither',
#    '115': 'tall',
#    '123': 'neither'},
#   'numGames': 5,
#   'games': ['5707-bffc7c59-37db-443f-b23c-7e8221ef5b8f',
#    '3329-ec77c178-2c61-46f2-a0fc-40fdc649bdee',
#    '4046-01bb62f2-1f0e-4425-9bc6-69132f477c71',
#    '7298-b991c134-4fe5-4202-a002-fedfafb9d169',
#    '0024-8f686741-7576-4c46-8d99-dd14992834f8'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b8'),
#   'partitionFamily': 1,
#   'splitNumber': 2,
#   'stimNumbers': ['023',
#    '029',
#    '052',
#    '060',
#    '066',
#    '076',
#    '083',
#    '093',
#    '094',
#    '098',
#    '100',
#    '103',
#    '121'],
#   'ntrials': 13,
#   'stimGroups': {'023': 'wide',
#    '029': 'neither',
#    '052': 'neither',
#    '060': 'neither',
#    '066': 'neither',
#    '076': 'neither',
#    '083': 'neither',
#    '093': 'neither',
#    '094': 'neither',
#    '098': 'neither',
#    '100': 'tall',
#    '103': 'neither',
#    '121': 'tall'},
#   'numGames': 5,
#   'games': ['0554-e12ab056-4f69-4dec-8543-24d712aaf240',
#    '2437-1711d3d0-454b-4ded-8c09-ae26b040f3ef',
#    '9898-acc5ff97-35e0-46e5-a8c8-8d3d7966d8d6',
#    '5193-aaf3b662-c933-44b6-8c4a-f22eea1e64e1',
#    '7354-ef3f5bc1-24e9-4b69-866a-d02340108ff3'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4b9'),
#   'partitionFamily': 1,
#   'splitNumber': 3,
#   'stimNumbers': ['003',
#    '022',
#    '032',
#    '034',
#    '037',
#    '043',
#    '044',
#    '049',
#    '053',
#    '070',
#    '101',
#    '124',
#    '127'],
#   'ntrials': 13,
#   'stimGroups': {'003': 'neither',
#    '022': 'wide',
#    '032': 'neither',
#    '034': 'neither',
#    '037': 'neither',
#    '043': 'neither',
#    '044': 'neither',
#    '049': 'neither',
#    '053': 'neither',
#    '070': 'neither',
#    '101': 'tall',
#    '124': 'neither',
#    '127': 'tall'},
#   'numGames': 5,
#   'games': ['8836-52195470-448d-4706-b712-2f11b710938d',
#    '8743-e2121ea5-e0c0-469b-8e07-5cd36700a8c6',
#    '5366-36d8fdf9-e28b-4797-a400-ab447364c5e9',
#    '8059-778ee843-4e44-4403-9982-334daf17b0b6',
#    '6387-8867005d-7653-4c38-bb3d-307640d4ba26'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4ba'),
#   'partitionFamily': 1,
#   'splitNumber': 4,
#   'stimNumbers': ['000',
#    '004',
#    '014',
#    '016',
#    '021',
#    '024',
#    '033',
#    '055',
#    '062',
#    '072',
#    '073',
#    '092',
#    '129'],
#   'ntrials': 13,
#   'stimGroups': {'000': 'neither',
#    '004': 'neither',
#    '014': 'wide',
#    '016': 'neither',
#    '021': 'neither',
#    '024': 'wide',
#    '033': 'neither',
#    '055': 'neither',
#    '062': 'neither',
#    '072': 'neither',
#    '073': 'neither',
#    '092': 'tall',
#    '129': 'tall'},
#   'numGames': 5,
#   'games': ['1753-3148cd2f-de3d-4622-8f7b-c38126289afb',
#    '4926-05ae4216-9dd9-448c-b581-b20678a488a9',
#    '3980-affbd135-d9c4-4ea2-b553-a9567dc47757',
#    '4241-95e2acda-0f40-42d7-8be2-35b7afbcc3af',
#    '1116-c9825eb3-2afa-4c9d-9914-bde5055bede7'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4bb'),
#   'partitionFamily': 1,
#   'splitNumber': 5,
#   'stimNumbers': ['010',
#    '013',
#    '038',
#    '039',
#    '045',
#    '048',
#    '050',
#    '051',
#    '074',
#    '082',
#    '099',
#    '111',
#    '126'],
#   'ntrials': 13,
#   'stimGroups': {'010': 'wide',
#    '013': 'wide',
#    '038': 'neither',
#    '039': 'neither',
#    '045': 'neither',
#    '048': 'neither',
#    '050': 'neither',
#    '051': 'neither',
#    '074': 'neither',
#    '082': 'neither',
#    '099': 'neither',
#    '111': 'tall',
#    '126': 'tall'},
#   'numGames': 5,
#   'games': ['4586-8c94a3e2-83c2-4f9f-909e-58b05ca85227',
#    '8538-5828aa9a-1a5d-4062-85c6-2068b35ac862',
#    '6595-d9d3e1dc-92b5-4602-bfc2-8f8e07fe8cc2',
#    '7706-e23e859c-56f6-40af-bbb5-3638d32d44d2',
#    '7646-d912a489-723b-4d17-a0fe-4360123e085a'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4bc'),
#   'partitionFamily': 1,
#   'splitNumber': 6,
#   'stimNumbers': ['001',
#    '018',
#    '028',
#    '047',
#    '056',
#    '063',
#    '071',
#    '079',
#    '084',
#    '085',
#    '102',
#    '109',
#    '110'],
#   'ntrials': 13,
#   'stimGroups': {'001': 'wide',
#    '018': 'wide',
#    '028': 'neither',
#    '047': 'neither',
#    '056': 'neither',
#    '063': 'neither',
#    '071': 'neither',
#    '079': 'neither',
#    '084': 'neither',
#    '085': 'neither',
#    '102': 'tall',
#    '109': 'tall',
#    '110': 'neither'},
#   'numGames': 5,
#   'games': ['6486-12d2bb15-9d5c-49f8-a671-5db88520447e',
#    '6839-40dd41df-50cb-49fa-afc6-736609bf48a7',
#    '9042-1ac2f942-51c1-4fdd-95a1-4659cfd43917',
#    '9926-85d5ee50-902e-4768-9e11-fad634522654',
#    '4468-5b156a0d-dfe8-4f20-b70c-8d9153ba196b'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4bd'),
#   'partitionFamily': 1,
#   'splitNumber': 7,
#   'stimNumbers': ['006',
#    '017',
#    '025',
#    '027',
#    '030',
#    '046',
#    '075',
#    '089',
#    '105',
#    '117',
#    '120',
#    '122',
#    '128'],
#   'ntrials': 13,
#   'stimGroups': {'006': 'wide',
#    '017': 'neither',
#    '025': 'wide',
#    '027': 'neither',
#    '030': 'neither',
#    '046': 'neither',
#    '075': 'neither',
#    '089': 'neither',
#    '105': 'neither',
#    '117': 'neither',
#    '120': 'neither',
#    '122': 'tall',
#    '128': 'tall'},
#   'numGames': 5,
#   'games': ['4732-c250ec9d-42b7-4936-98ab-d1b6cfb41d70',
#    '2123-d3a81c7f-dcaa-4473-80a5-b4201fdc6bed',
#    '9350-ad8f76dd-1a8d-46fe-81e4-46d01c1680ff',
#    '4055-cfab8eac-9c46-48c0-90f8-a945494dcd8d',
#    '1549-80d7b54e-1687-4a10-ad67-eb9bfd0428e6'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4be'),
#   'partitionFamily': 1,
#   'splitNumber': 8,
#   'stimNumbers': ['009',
#    '011',
#    '015',
#    '026',
#    '054',
#    '058',
#    '067',
#    '069',
#    '081',
#    '097',
#    '106',
#    '112',
#    '114'],
#   'ntrials': 13,
#   'stimGroups': {'009': 'neither',
#    '011': 'wide',
#    '015': 'wide',
#    '026': 'neither',
#    '054': 'neither',
#    '058': 'neither',
#    '067': 'neither',
#    '069': 'neither',
#    '081': 'neither',
#    '097': 'tall',
#    '106': 'neither',
#    '112': 'neither',
#    '114': 'tall'},
#   'numGames': 5,
#   'games': ['8531-b2a52f28-b4f2-400c-90fc-17a7983bf4f4',
#    '6977-d58cec5b-db36-4862-8b5e-f11b655eef2b',
#    '6053-11d379ce-7a98-400e-86be-5b8498752705',
#    '3129-ef2f2c41-4031-4a70-b18c-c8b80069eb63',
#    '6179-9a9a859e-4832-4400-addd-c9f25a6840e9'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0},
#  {'_id': ObjectId('611bfd71767fe421dbdca4bf'),
#   'partitionFamily': 1,
#   'splitNumber': 9,
#   'stimNumbers': ['007',
#    '008',
#    '020',
#    '031',
#    '041',
#    '042',
#    '059',
#    '061',
#    '065',
#    '087',
#    '090',
#    '116',
#    '118'],
#   'ntrials': 13,
#   'stimGroups': {'007': 'neither',
#    '008': 'wide',
#    '020': 'wide',
#    '031': 'neither',
#    '041': 'neither',
#    '042': 'neither',
#    '059': 'neither',
#    '061': 'neither',
#    '065': 'neither',
#    '087': 'neither',
#    '090': 'neither',
#    '116': 'tall',
#    '118': 'tall'},
#   'numGames': 5,
#   'games': ['1501-6db78408-cc97-43a7-8d05-348be6c524e9',
#    '3827-d113d912-9313-48b0-9185-a0e734897c7f',
#    '3079-614edb78-db91-4e5f-8504-f0c965f68a2a',
#    '3248-3ba3c545-cf96-45f0-9c05-d96bd9f55a4b',
#    '7170-a325d7d5-5b84-4baa-b740-8fc46e55eb3c'],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'ca_prior_elicitation_4_block_unique_silhouettes_procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0}]

# %% [markdown]
# ## Test which versions have been run
#
# This grabs the dataframe created by data generator, to see which records need to be run more times.
#
# It wipes the metadata from mongo, and replaces it with individual records for each additional partition that needs to be run.

# %%
version = 'procedural'
# version = 'categorization'

# %%
# WARNING: THIS JUST GRABS A LOCAL CSV. ENSURE YOU HAVE CREATED THIS WITH DATA GENERATOR NOTEBOOK

run_results_through_data_generator = True


if run_results_through_data_generator:
    results_csv_directory = "../../results/csv"
    # print("Possible CSV results files to load:")
    # print(os.listdir(results_csv_directory))

    result_csv = 'lax-tower-4-block-unique-silhouettes-' + version +'-pilot_3.csv'

    df_trial = pd.read_csv(os.path.join(results_csv_directory, result_csv))

# %%
complete_counts = (df_trial.groupby(['partitionFamily','splitNumber']).count()/13)['datatype'].reset_index()
complete_counts
# Out:
#     partitionFamily  splitNumber  datatype
# 0               0.0          0.0       6.0
# 1               0.0          1.0       5.0
# 2               0.0          2.0       5.0
# 3               0.0          3.0       5.0
# 4               0.0          4.0       5.0
# 5               0.0          5.0       5.0
# 6               0.0          6.0       5.0
# 7               0.0          7.0       5.0
# 8               0.0          8.0       5.0
# 9               0.0          9.0       5.0
# 10              1.0          0.0       5.0
# 11              1.0          1.0       5.0
# 12              1.0          2.0       5.0
# 13              1.0          3.0       5.0
# 14              1.0          4.0       5.0
# 15              1.0          5.0       5.0
# 16              1.0          6.0       5.0
# 17              1.0          7.0       5.0
# 18              1.0          8.0       5.0
# 19              1.0          9.0       5.0

# %%
# add a record in metadata for each additional time it needs to be run

n_expected = 5

extra_metadata = []

for f in range(0, n_families):
    for s in range(0,n_splits):
        
        n_completed = complete_counts[(complete_counts.partitionFamily == f) & (complete_counts.splitNumber == s)]\
            .reset_index().loc[0,'datatype']
        
        i = n_completed
        
        while i < n_expected:
            
            i = i + 1

            stim_numbers = list(silhouette_superset.groupby('family_'+str(f)).get_group(s)['tower_number_str'])
    #         print(stim_numbers)
            extra_metadata.append(
                {
                    'partitionFamily': f,
                    'splitNumber': s,
                    'stimNumbers': stim_numbers,
                    'ntrials': len(stim_numbers),
                    'stimGroups': {n: silhouette_superset.groupby('family_'+str(f)).get_group(s).reset_index().loc[i,'group'] for i, n in enumerate(stim_numbers)},
                    'numGames': 0,
                    'games': [],
                    'experimentType': 'prior_elicitation',
                    'experimentName': experiment_name,
                    's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
                    'versionInd': versionInd,
                    'extra_metadata_index': i
                })

# %%
print(str(len(extra_metadata)) + ' extra records to upload')
# Out:
# 0 extra records to upload

# %%
# Delete metadata from db
really_run = True

if really_run:
    db.drop_collection(experiment_name)

# %%
## now, iterate through each version and insert into mongo
## loop through list of records and insert each into collection
reallyRun = True
if reallyRun:
    for (i,j) in enumerate(extra_metadata):        
        coll.insert_one(j)
        print('Inserted version {} of stimDict.'.format(j['versionInd']))
        clear_output(wait=True)

else:
    print('Did not insert any new data.')
# Out:
# Inserted version 0 of stimDict.

# %%
list(coll.find())
# Out:
# [{'_id': ObjectId('61241d4480612a35577a218c'),
#   'partitionFamily': 0,
#   'splitNumber': 1,
#   'stimNumbers': ['007',
#    '009',
#    '019',
#    '023',
#    '053',
#    '061',
#    '062',
#    '072',
#    '076',
#    '084',
#    '086',
#    '106',
#    '115'],
#   'ntrials': 13,
#   'stimGroups': {'007': 'neither',
#    '009': 'neither',
#    '019': 'wide',
#    '023': 'wide',
#    '053': 'neither',
#    '061': 'neither',
#    '062': 'neither',
#    '072': 'neither',
#    '076': 'neither',
#    '084': 'neither',
#    '086': 'neither',
#    '106': 'neither',
#    '115': 'tall'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0,
#   'extra_metadata_index': 5.0},
#  {'_id': ObjectId('61241d4480612a35577a218d'),
#   'partitionFamily': 0,
#   'splitNumber': 9,
#   'stimNumbers': ['006',
#    '022',
#    '031',
#    '032',
#    '047',
#    '048',
#    '066',
#    '089',
#    '090',
#    '094',
#    '117',
#    '121',
#    '128'],
#   'ntrials': 13,
#   'stimGroups': {'006': 'wide',
#    '022': 'wide',
#    '031': 'neither',
#    '032': 'neither',
#    '047': 'neither',
#    '048': 'neither',
#    '066': 'neither',
#    '089': 'neither',
#    '090': 'neither',
#    '094': 'neither',
#    '117': 'neither',
#    '121': 'tall',
#    '128': 'tall'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0,
#   'extra_metadata_index': 5.0},
#  {'_id': ObjectId('61241d4480612a35577a218e'),
#   'partitionFamily': 1,
#   'splitNumber': 0,
#   'stimNumbers': ['002',
#    '005',
#    '036',
#    '064',
#    '068',
#    '077',
#    '080',
#    '086',
#    '104',
#    '107',
#    '113',
#    '119',
#    '125'],
#   'ntrials': 13,
#   'stimGroups': {'002': 'wide',
#    '005': 'wide',
#    '036': 'neither',
#    '064': 'neither',
#    '068': 'neither',
#    '077': 'neither',
#    '080': 'neither',
#    '086': 'neither',
#    '104': 'neither',
#    '107': 'neither',
#    '113': 'neither',
#    '119': 'neither',
#    '125': 'tall'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0,
#   'extra_metadata_index': 4.0},
#  {'_id': ObjectId('61241d4480612a35577a218f'),
#   'partitionFamily': 1,
#   'splitNumber': 0,
#   'stimNumbers': ['002',
#    '005',
#    '036',
#    '064',
#    '068',
#    '077',
#    '080',
#    '086',
#    '104',
#    '107',
#    '113',
#    '119',
#    '125'],
#   'ntrials': 13,
#   'stimGroups': {'002': 'wide',
#    '005': 'wide',
#    '036': 'neither',
#    '064': 'neither',
#    '068': 'neither',
#    '077': 'neither',
#    '080': 'neither',
#    '086': 'neither',
#    '104': 'neither',
#    '107': 'neither',
#    '113': 'neither',
#    '119': 'neither',
#    '125': 'tall'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0,
#   'extra_metadata_index': 5.0},
#  {'_id': ObjectId('61241d4480612a35577a2190'),
#   'partitionFamily': 1,
#   'splitNumber': 2,
#   'stimNumbers': ['023',
#    '029',
#    '052',
#    '060',
#    '066',
#    '076',
#    '083',
#    '093',
#    '094',
#    '098',
#    '100',
#    '103',
#    '121'],
#   'ntrials': 13,
#   'stimGroups': {'023': 'wide',
#    '029': 'neither',
#    '052': 'neither',
#    '060': 'neither',
#    '066': 'neither',
#    '076': 'neither',
#    '083': 'neither',
#    '093': 'neither',
#    '094': 'neither',
#    '098': 'neither',
#    '100': 'tall',
#    '103': 'neither',
#    '121': 'tall'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0,
#   'extra_metadata_index': 5.0},
#  {'_id': ObjectId('61241d4480612a35577a2191'),
#   'partitionFamily': 1,
#   'splitNumber': 6,
#   'stimNumbers': ['001',
#    '018',
#    '028',
#    '047',
#    '056',
#    '063',
#    '071',
#    '079',
#    '084',
#    '085',
#    '102',
#    '109',
#    '110'],
#   'ntrials': 13,
#   'stimGroups': {'001': 'wide',
#    '018': 'wide',
#    '028': 'neither',
#    '047': 'neither',
#    '056': 'neither',
#    '063': 'neither',
#    '071': 'neither',
#    '079': 'neither',
#    '084': 'neither',
#    '085': 'neither',
#    '102': 'tall',
#    '109': 'tall',
#    '110': 'neither'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'prior_elicitation',
#   'experimentName': 'procedural',
#   's3_bucket': 'lax-tower-4-block-unique-silhouettes-json',
#   'versionInd': 0,
#   'extra_metadata_index': 5.0}]

# %%
experiment_name

# %%
# metadata_pre_top_up = pd.DataFrame(coll.find())

# metadata_pre_top_up.to_csv('./metadata/first_batch_procedural.csv')

# %%
experiment_name
# Out:
# 'ca_prior_elicitation_4_block_unique_silhouettes_categorization'
