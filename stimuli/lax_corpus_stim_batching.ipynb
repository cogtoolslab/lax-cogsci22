# %% [markdown]
# # Stimulus batching

# %% [markdown]
# ## Uploading stimuli
#
# Creates metadata for corpus collection on gadget and structure domains.
#
# Partitions train/test data into batches of 25 stimuli (20 train and 5 test).
#
# Multiple families of batches can be specified.
#
#
#
# **Original metadata** for each domain are uploaded individually (i.e. with a single sweep of the notebook from here to TOPUP BATCH).
#
# **Topup metadata** are uploaded to a separate database, but done all together.
# This uploads a single record for every one participant missing from that batch.

# %%
from __future__ import division

import numpy as np
import os, sys
from PIL import Image
import pandas as pd
import json
import pickle
import ast

from matplotlib import pylab, mlab, pyplot
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.path import Path
import matplotlib.patches as patches
# %matplotlib inline

from IPython.core.pylabtools import figsize, getfigs

import seaborn as sns
from sklearn.model_selection import StratifiedKFold

import random
from functools import reduce

from scipy.stats import norm
from IPython.display import clear_output

import copy
import importlib

# import urllib library
from urllib.request import urlopen

### Add Paths

## root paths
curr_dir = os.getcwd()
proj_dir = os.path.abspath(os.path.join(curr_dir,'..')) ## u\e relative paths

## add helpers to python path
import sys
if os.path.join(proj_dir, 'stimuli') not in sys.path:
    sys.path.append(os.path.join(proj_dir, 'stimuli'))

# %% [markdown]
# ### Data storage setup

# %%
s3_bucket_path_template = "https://lax-{}-{}-all.s3.amazonaws.com/"

# %%
subdomains = {
    'structures' :  ['bridge', 'castle', 'house', 'city'],
    'drawing' :  ['nuts-bolts','wheels','furniture','dials']
}

domains = list(subdomains.keys())

# %%
domain = domains[0]
subdomain = subdomains[domain][0]
print(domain + ', ' + subdomain)
# Out:
# structures, bridge

# %% [markdown]
# ### Get stimulus data from S3

# %%
def get_stim_df(domain, subdomain):

    experiment_name = 'lax_{}_{}_10'.format(domain, subdomain)

    # generate bucket path
    s3_bucket_path = s3_bucket_path_template.format(domain, subdomain)

    if domain == 'structures':
        # read manifest data
        df = pd.read_csv(s3_bucket_path + 'df_{}.csv'.format(subdomain))

        # estimated complexity
        df.loc[0:50, 'estimated_complexity'] = 'low'
        df.loc[50:, 'estimated_complexity'] = 'high'

        # assign grouping column
    #     df['group'] = np.where(df['train'], 'train', 'test')
        df['group'] = df['estimated_complexity']

        # assign id column
        df['stim_id'] = df['structure_number'] 


    elif domain == 'drawing':

        # read manifest data
        df = pd.read_csv(s3_bucket_path + 'manifest.csv'.format(subdomain))

        # estimated complexity
        df.loc[0:50, 'estimated_complexity'] = 'low'
        df.loc[50:, 'estimated_complexity'] = 'high'

        # assign grouping column
    #     df['group'] = df['data_split']
        df['group'] = df['estimated_complexity']

        # assign id column
        df['stim_id'] = df['stim_id'].apply(lambda x: x[-3:])
        
    df['experiment_name'] = experiment_name
    df['s3_bucket_path'] = s3_bucket_path
        
    return df

# %%
df = get_stim_df(domain, subdomain)

# %% [markdown]
# ## Generate splits

# %%
def generate_splits(df, 
                    n_families = 2,
                    n_splits = 25,
                    id_column = 'stim_id',
                    grouping_column = 'group',
                    verbose = False):
    
    # batch size = len(df) / n_splits
    
    groups = df[[id_column,grouping_column]]
   
    if verbose:
        print(groups['group'].value_counts())
    
    X = df[id_column]
    y = df[grouping_column]

    for i in range(0, n_families):

        # set up partitioning
        skf = StratifiedKFold(n_splits=n_splits, 
                              random_state=i,  # tie random state to group num
                              shuffle=True)

        # apply partitioning and save to df
        for split_num, (train_index, test_index) in enumerate(skf.split(X, y)):
            df.loc[test_index,'family_'+str(i)] = split_num
    #         print(groups.loc[test_index])
    
    if verbose:
        print(str(n_splits) + ' splits generated in each of ' + str(n_families) + ' families')
        
    return df

# %%
df = generate_splits(df)
# Out:
# high    200
# low      50
# Name: group, dtype: int64
# 25 splits generated in each of 2 families

# %% [markdown]
# ## To run multiple versions, upload the same metadate to separate collections, and update stimColName in configs accordingly

# %%
versionInd = 0

# %%
# connect to mongo

import pymongo as pm

# set vars 
auth = pd.read_csv('../auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'cogtoolslab.org' ## experiment server ip address

conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
db = conn['stimuli']
coll = db[df['experiment_name'][0]]

# %%
# convert to lists of stimulus names

assert subdomain in df['experiment_name'][0]
assert subdomain in coll.name

metadata = []

for f in range(0, n_families):
    for s in range(0,n_splits):
        stimIDs = list(df.groupby('family_'+str(f)).get_group(s)['stim_id'].apply(lambda x: str(x).zfill(3)))
#         print(stim_numbers)
        metadata.append(
            {
                'partitionFamily': f,
                'splitNumber': s,
                'stimIDs': stimIDs,
                'stimURLS': [s3_bucket_path + "lax-{}-{}-{}-{}.png".format(domain,
                                                              subdomain,
                                                              (stimID if domain=='structures' else 'all'),
                                                              ('all' if domain=='structures' else stimID))\
                            for stimID in stimIDs],
                'ntrials': len(stimIDs),
                'stimGroups': {n: df.groupby('family_'+str(f)).get_group(s).reset_index().loc[i,'group'] for i, n in enumerate(stimIDs)},
                'numGames': 0,
                'games': [],
                'experimentType': 'corpus_collection',
                'experimentName': df['experiment_name'][0],
                's3_bucket_url': s3_bucket_path,
                'versionInd': versionInd
            })

# %%
metadata
# Out:
# [{'partitionFamily': 0,
#   'splitNumber': 0,
#   'stimIDs': ['034',
#    '047',
#    '071',
#    '090',
#    '132',
#    '145',
#    '161',
#    '199',
#    '216',
#    '235'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-034-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-047-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-071-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-090-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-132-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-145-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-161-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-199-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-216-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-235-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'034': 'low',
#    '047': 'low',
#    '071': 'high',
#    '090': 'high',
#    '132': 'high',
#    '145': 'high',
#    '161': 'high',
#    '199': 'high',
#    '216': 'high',
#    '235': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 1,
#   'stimIDs': ['004',
#    '046',
#    '056',
#    '070',
#    '094',
#    '113',
#    '143',
#    '166',
#    '171',
#    '228'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-004-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-046-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-056-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-070-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-094-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-113-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-143-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-166-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-171-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-228-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'004': 'low',
#    '046': 'low',
#    '056': 'high',
#    '070': 'high',
#    '094': 'high',
#    '113': 'high',
#    '143': 'high',
#    '166': 'high',
#    '171': 'high',
#    '228': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 2,
#   'stimIDs': ['009',
#    '030',
#    '091',
#    '111',
#    '123',
#    '126',
#    '154',
#    '175',
#    '208',
#    '243'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-009-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-030-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-091-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-111-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-123-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-126-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-154-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-175-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-208-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-243-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'009': 'low',
#    '030': 'low',
#    '091': 'high',
#    '111': 'high',
#    '123': 'high',
#    '126': 'high',
#    '154': 'high',
#    '175': 'high',
#    '208': 'high',
#    '243': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 3,
#   'stimIDs': ['015',
#    '038',
#    '084',
#    '122',
#    '124',
#    '138',
#    '147',
#    '148',
#    '172',
#    '237'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-015-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-038-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-084-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-122-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-124-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-138-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-147-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-148-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-172-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-237-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'015': 'low',
#    '038': 'low',
#    '084': 'high',
#    '122': 'high',
#    '124': 'high',
#    '138': 'high',
#    '147': 'high',
#    '148': 'high',
#    '172': 'high',
#    '237': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 4,
#   'stimIDs': ['027',
#    '043',
#    '058',
#    '074',
#    '079',
#    '119',
#    '158',
#    '197',
#    '231',
#    '244'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-027-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-043-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-058-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-074-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-079-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-119-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-158-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-197-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-231-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-244-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'027': 'low',
#    '043': 'low',
#    '058': 'high',
#    '074': 'high',
#    '079': 'high',
#    '119': 'high',
#    '158': 'high',
#    '197': 'high',
#    '231': 'high',
#    '244': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 5,
#   'stimIDs': ['001',
#    '002',
#    '065',
#    '101',
#    '142',
#    '170',
#    '177',
#    '186',
#    '215',
#    '239'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-001-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-002-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-065-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-101-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-142-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-170-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-177-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-186-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-215-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-239-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'001': 'low',
#    '002': 'low',
#    '065': 'high',
#    '101': 'high',
#    '142': 'high',
#    '170': 'high',
#    '177': 'high',
#    '186': 'high',
#    '215': 'high',
#    '239': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 6,
#   'stimIDs': ['028',
#    '035',
#    '061',
#    '136',
#    '157',
#    '160',
#    '173',
#    '203',
#    '204',
#    '246'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-028-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-035-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-061-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-136-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-157-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-160-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-173-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-203-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-204-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-246-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'028': 'low',
#    '035': 'low',
#    '061': 'high',
#    '136': 'high',
#    '157': 'high',
#    '160': 'high',
#    '173': 'high',
#    '203': 'high',
#    '204': 'high',
#    '246': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 7,
#   'stimIDs': ['016',
#    '020',
#    '072',
#    '108',
#    '134',
#    '150',
#    '151',
#    '169',
#    '180',
#    '232'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-016-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-020-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-072-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-108-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-134-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-150-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-151-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-169-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-180-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-232-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'016': 'low',
#    '020': 'low',
#    '072': 'high',
#    '108': 'high',
#    '134': 'high',
#    '150': 'high',
#    '151': 'high',
#    '169': 'high',
#    '180': 'high',
#    '232': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 8,
#   'stimIDs': ['023',
#    '031',
#    '057',
#    '097',
#    '100',
#    '135',
#    '137',
#    '202',
#    '217',
#    '234'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-023-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-031-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-057-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-097-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-100-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-135-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-137-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-202-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-217-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-234-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'023': 'low',
#    '031': 'low',
#    '057': 'high',
#    '097': 'high',
#    '100': 'high',
#    '135': 'high',
#    '137': 'high',
#    '202': 'high',
#    '217': 'high',
#    '234': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 9,
#   'stimIDs': ['014',
#    '042',
#    '053',
#    '078',
#    '104',
#    '128',
#    '141',
#    '149',
#    '211',
#    '242'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-014-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-042-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-053-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-078-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-104-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-128-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-141-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-149-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-211-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-242-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'014': 'low',
#    '042': 'low',
#    '053': 'high',
#    '078': 'high',
#    '104': 'high',
#    '128': 'high',
#    '141': 'high',
#    '149': 'high',
#    '211': 'high',
#    '242': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 10,
#   'stimIDs': ['025',
#    '041',
#    '052',
#    '076',
#    '159',
#    '165',
#    '174',
#    '205',
#    '218',
#    '226'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-025-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-041-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-052-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-076-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-159-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-165-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-174-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-205-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-218-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-226-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'025': 'low',
#    '041': 'low',
#    '052': 'high',
#    '076': 'high',
#    '159': 'high',
#    '165': 'high',
#    '174': 'high',
#    '205': 'high',
#    '218': 'high',
#    '226': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 11,
#   'stimIDs': ['008',
#    '039',
#    '066',
#    '080',
#    '081',
#    '110',
#    '195',
#    '200',
#    '201',
#    '225'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-008-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-039-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-066-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-080-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-081-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-110-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-195-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-200-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-201-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-225-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'008': 'low',
#    '039': 'low',
#    '066': 'high',
#    '080': 'high',
#    '081': 'high',
#    '110': 'high',
#    '195': 'high',
#    '200': 'high',
#    '201': 'high',
#    '225': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 12,
#   'stimIDs': ['029',
#    '037',
#    '073',
#    '083',
#    '125',
#    '127',
#    '193',
#    '212',
#    '222',
#    '230'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-029-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-037-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-073-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-083-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-125-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-127-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-193-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-212-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-222-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-230-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'029': 'low',
#    '037': 'low',
#    '073': 'high',
#    '083': 'high',
#    '125': 'high',
#    '127': 'high',
#    '193': 'high',
#    '212': 'high',
#    '222': 'high',
#    '230': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 13,
#   'stimIDs': ['005',
#    '012',
#    '051',
#    '063',
#    '107',
#    '109',
#    '118',
#    '146',
#    '163',
#    '240'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-005-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-012-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-051-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-063-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-107-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-109-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-118-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-146-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-163-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-240-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'005': 'low',
#    '012': 'low',
#    '051': 'high',
#    '063': 'high',
#    '107': 'high',
#    '109': 'high',
#    '118': 'high',
#    '146': 'high',
#    '163': 'high',
#    '240': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 14,
#   'stimIDs': ['000',
#    '019',
#    '077',
#    '085',
#    '093',
#    '187',
#    '191',
#    '198',
#    '206',
#    '229'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-000-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-019-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-077-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-085-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-093-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-187-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-191-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-198-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-206-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-229-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'000': 'low',
#    '019': 'low',
#    '077': 'high',
#    '085': 'high',
#    '093': 'high',
#    '187': 'high',
#    '191': 'high',
#    '198': 'high',
#    '206': 'high',
#    '229': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 15,
#   'stimIDs': ['007',
#    '021',
#    '082',
#    '086',
#    '102',
#    '129',
#    '179',
#    '214',
#    '219',
#    '236'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-007-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-021-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-082-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-086-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-102-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-129-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-179-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-214-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-219-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-236-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'007': 'low',
#    '021': 'low',
#    '082': 'high',
#    '086': 'high',
#    '102': 'high',
#    '129': 'high',
#    '179': 'high',
#    '214': 'high',
#    '219': 'high',
#    '236': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 16,
#   'stimIDs': ['010',
#    '022',
#    '089',
#    '099',
#    '153',
#    '183',
#    '213',
#    '241',
#    '245',
#    '249'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-010-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-022-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-089-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-099-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-153-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-183-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-213-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-241-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-245-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-249-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'010': 'low',
#    '022': 'low',
#    '089': 'high',
#    '099': 'high',
#    '153': 'high',
#    '183': 'high',
#    '213': 'high',
#    '241': 'high',
#    '245': 'high',
#    '249': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 17,
#   'stimIDs': ['011',
#    '013',
#    '068',
#    '156',
#    '164',
#    '188',
#    '207',
#    '210',
#    '220',
#    '223'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-011-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-013-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-068-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-156-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-164-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-188-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-207-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-210-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-220-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-223-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'011': 'low',
#    '013': 'low',
#    '068': 'high',
#    '156': 'high',
#    '164': 'high',
#    '188': 'high',
#    '207': 'high',
#    '210': 'high',
#    '220': 'high',
#    '223': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 18,
#   'stimIDs': ['036',
#    '040',
#    '069',
#    '096',
#    '098',
#    '116',
#    '144',
#    '167',
#    '189',
#    '209'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-036-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-040-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-069-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-096-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-098-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-116-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-144-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-167-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-189-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-209-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'036': 'low',
#    '040': 'low',
#    '069': 'high',
#    '096': 'high',
#    '098': 'high',
#    '116': 'high',
#    '144': 'high',
#    '167': 'high',
#    '189': 'high',
#    '209': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 19,
#   'stimIDs': ['006',
#    '044',
#    '059',
#    '064',
#    '075',
#    '130',
#    '131',
#    '140',
#    '184',
#    '196'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-006-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-044-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-059-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-064-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-075-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-130-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-131-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-140-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-184-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-196-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'006': 'low',
#    '044': 'low',
#    '059': 'high',
#    '064': 'high',
#    '075': 'high',
#    '130': 'high',
#    '131': 'high',
#    '140': 'high',
#    '184': 'high',
#    '196': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 20,
#   'stimIDs': ['003',
#    '032',
#    '050',
#    '088',
#    '105',
#    '114',
#    '121',
#    '181',
#    '194',
#    '247'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-003-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-032-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-050-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-088-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-105-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-114-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-121-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-181-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-194-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-247-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'003': 'low',
#    '032': 'low',
#    '050': 'high',
#    '088': 'high',
#    '105': 'high',
#    '114': 'high',
#    '121': 'high',
#    '181': 'high',
#    '194': 'high',
#    '247': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 21,
#   'stimIDs': ['024',
#    '026',
#    '055',
#    '120',
#    '139',
#    '152',
#    '176',
#    '185',
#    '227',
#    '233'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-024-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-026-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-055-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-120-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-139-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-152-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-176-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-185-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-227-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-233-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'024': 'low',
#    '026': 'low',
#    '055': 'high',
#    '120': 'high',
#    '139': 'high',
#    '152': 'high',
#    '176': 'high',
#    '185': 'high',
#    '227': 'high',
#    '233': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 22,
#   'stimIDs': ['017',
#    '049',
#    '054',
#    '060',
#    '087',
#    '092',
#    '095',
#    '162',
#    '178',
#    '182'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-017-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-049-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-054-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-060-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-087-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-092-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-095-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-162-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-178-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-182-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'017': 'low',
#    '049': 'low',
#    '054': 'high',
#    '060': 'high',
#    '087': 'high',
#    '092': 'high',
#    '095': 'high',
#    '162': 'high',
#    '178': 'high',
#    '182': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 23,
#   'stimIDs': ['045',
#    '048',
#    '103',
#    '106',
#    '112',
#    '117',
#    '133',
#    '168',
#    '192',
#    '238'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-045-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-048-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-103-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-106-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-112-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-117-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-133-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-168-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-192-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-238-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'045': 'low',
#    '048': 'low',
#    '103': 'high',
#    '106': 'high',
#    '112': 'high',
#    '117': 'high',
#    '133': 'high',
#    '168': 'high',
#    '192': 'high',
#    '238': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 0,
#   'splitNumber': 24,
#   'stimIDs': ['018',
#    '033',
#    '062',
#    '067',
#    '115',
#    '155',
#    '190',
#    '221',
#    '224',
#    '248'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-018-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-033-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-062-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-067-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-115-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-155-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-190-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-221-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-224-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-248-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'018': 'low',
#    '033': 'low',
#    '062': 'high',
#    '067': 'high',
#    '115': 'high',
#    '155': 'high',
#    '190': 'high',
#    '221': 'high',
#    '224': 'high',
#    '248': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 0,
#   'stimIDs': ['039',
#    '041',
#    '052',
#    '059',
#    '099',
#    '145',
#    '194',
#    '196',
#    '198',
#    '244'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-039-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-041-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-052-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-059-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-099-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-145-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-194-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-196-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-198-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-244-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'039': 'low',
#    '041': 'low',
#    '052': 'high',
#    '059': 'high',
#    '099': 'high',
#    '145': 'high',
#    '194': 'high',
#    '196': 'high',
#    '198': 'high',
#    '244': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 1,
#   'stimIDs': ['004',
#    '005',
#    '083',
#    '097',
#    '130',
#    '169',
#    '181',
#    '212',
#    '225',
#    '234'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-004-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-005-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-083-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-097-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-130-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-169-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-181-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-212-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-225-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-234-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'004': 'low',
#    '005': 'low',
#    '083': 'high',
#    '097': 'high',
#    '130': 'high',
#    '169': 'high',
#    '181': 'high',
#    '212': 'high',
#    '225': 'high',
#    '234': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 2,
#   'stimIDs': ['025',
#    '043',
#    '088',
#    '091',
#    '108',
#    '132',
#    '144',
#    '189',
#    '223',
#    '226'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-025-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-043-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-088-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-091-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-108-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-132-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-144-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-189-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-223-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-226-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'025': 'low',
#    '043': 'low',
#    '088': 'high',
#    '091': 'high',
#    '108': 'high',
#    '132': 'high',
#    '144': 'high',
#    '189': 'high',
#    '223': 'high',
#    '226': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 3,
#   'stimIDs': ['036',
#    '037',
#    '068',
#    '087',
#    '098',
#    '107',
#    '188',
#    '232',
#    '240',
#    '243'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-036-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-037-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-068-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-087-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-098-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-107-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-188-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-232-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-240-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-243-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'036': 'low',
#    '037': 'low',
#    '068': 'high',
#    '087': 'high',
#    '098': 'high',
#    '107': 'high',
#    '188': 'high',
#    '232': 'high',
#    '240': 'high',
#    '243': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 4,
#   'stimIDs': ['045',
#    '046',
#    '051',
#    '071',
#    '078',
#    '086',
#    '094',
#    '096',
#    '187',
#    '214'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-045-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-046-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-051-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-071-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-078-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-086-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-094-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-096-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-187-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-214-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'045': 'low',
#    '046': 'low',
#    '051': 'high',
#    '071': 'high',
#    '078': 'high',
#    '086': 'high',
#    '094': 'high',
#    '096': 'high',
#    '187': 'high',
#    '214': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 5,
#   'stimIDs': ['029',
#    '044',
#    '081',
#    '114',
#    '116',
#    '143',
#    '184',
#    '205',
#    '235',
#    '242'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-029-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-044-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-081-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-114-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-116-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-143-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-184-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-205-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-235-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-242-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'029': 'low',
#    '044': 'low',
#    '081': 'high',
#    '114': 'high',
#    '116': 'high',
#    '143': 'high',
#    '184': 'high',
#    '205': 'high',
#    '235': 'high',
#    '242': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 6,
#   'stimIDs': ['019',
#    '047',
#    '067',
#    '070',
#    '135',
#    '138',
#    '148',
#    '155',
#    '239',
#    '246'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-019-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-047-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-067-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-070-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-135-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-138-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-148-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-155-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-239-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-246-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'019': 'low',
#    '047': 'low',
#    '067': 'high',
#    '070': 'high',
#    '135': 'high',
#    '138': 'high',
#    '148': 'high',
#    '155': 'high',
#    '239': 'high',
#    '246': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 7,
#   'stimIDs': ['027',
#    '042',
#    '056',
#    '079',
#    '082',
#    '125',
#    '133',
#    '134',
#    '166',
#    '245'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-027-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-042-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-056-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-079-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-082-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-125-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-133-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-134-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-166-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-245-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'027': 'low',
#    '042': 'low',
#    '056': 'high',
#    '079': 'high',
#    '082': 'high',
#    '125': 'high',
#    '133': 'high',
#    '134': 'high',
#    '166': 'high',
#    '245': 'high'},
# ...
#    '063',
#    '072',
#    '074',
#    '075',
#    '105',
#    '123',
#    '202',
#    '236'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-007-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-030-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-063-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-072-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-074-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-075-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-105-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-123-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-202-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-236-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'007': 'low',
#    '030': 'low',
#    '063': 'high',
#    '072': 'high',
#    '074': 'high',
#    '075': 'high',
#    '105': 'high',
#    '123': 'high',
#    '202': 'high',
#    '236': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 15,
#   'stimIDs': ['009',
#    '028',
#    '057',
#    '077',
#    '090',
#    '159',
#    '175',
#    '178',
#    '222',
#    '224'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-009-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-028-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-057-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-077-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-090-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-159-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-175-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-178-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-222-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-224-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'009': 'low',
#    '028': 'low',
#    '057': 'high',
#    '077': 'high',
#    '090': 'high',
#    '159': 'high',
#    '175': 'high',
#    '178': 'high',
#    '222': 'high',
#    '224': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 16,
#   'stimIDs': ['010',
#    '026',
#    '089',
#    '109',
#    '110',
#    '154',
#    '156',
#    '199',
#    '230',
#    '248'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-010-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-026-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-089-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-109-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-110-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-154-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-156-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-199-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-230-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-248-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'010': 'low',
#    '026': 'low',
#    '089': 'high',
#    '109': 'high',
#    '110': 'high',
#    '154': 'high',
#    '156': 'high',
#    '199': 'high',
#    '230': 'high',
#    '248': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 17,
#   'stimIDs': ['001',
#    '032',
#    '053',
#    '080',
#    '085',
#    '118',
#    '128',
#    '171',
#    '210',
#    '215'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-001-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-032-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-053-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-080-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-085-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-118-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-128-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-171-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-210-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-215-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'001': 'low',
#    '032': 'low',
#    '053': 'high',
#    '080': 'high',
#    '085': 'high',
#    '118': 'high',
#    '128': 'high',
#    '171': 'high',
#    '210': 'high',
#    '215': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 18,
#   'stimIDs': ['013',
#    '049',
#    '103',
#    '104',
#    '127',
#    '161',
#    '185',
#    '191',
#    '204',
#    '247'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-013-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-049-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-103-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-104-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-127-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-161-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-185-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-191-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-204-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-247-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'013': 'low',
#    '049': 'low',
#    '103': 'high',
#    '104': 'high',
#    '127': 'high',
#    '161': 'high',
#    '185': 'high',
#    '191': 'high',
#    '204': 'high',
#    '247': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 19,
#   'stimIDs': ['003',
#    '011',
#    '101',
#    '131',
#    '153',
#    '172',
#    '173',
#    '193',
#    '220',
#    '228'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-003-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-011-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-101-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-131-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-153-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-172-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-173-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-193-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-220-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-228-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'003': 'low',
#    '011': 'low',
#    '101': 'high',
#    '131': 'high',
#    '153': 'high',
#    '172': 'high',
#    '173': 'high',
#    '193': 'high',
#    '220': 'high',
#    '228': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 20,
#   'stimIDs': ['002',
#    '020',
#    '065',
#    '126',
#    '170',
#    '179',
#    '180',
#    '213',
#    '216',
#    '219'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-002-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-020-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-065-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-126-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-170-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-179-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-180-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-213-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-216-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-219-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'002': 'low',
#    '020': 'low',
#    '065': 'high',
#    '126': 'high',
#    '170': 'high',
#    '179': 'high',
#    '180': 'high',
#    '213': 'high',
#    '216': 'high',
#    '219': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 21,
#   'stimIDs': ['015',
#    '048',
#    '064',
#    '100',
#    '121',
#    '122',
#    '142',
#    '158',
#    '183',
#    '211'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-015-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-048-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-064-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-100-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-121-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-122-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-142-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-158-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-183-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-211-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'015': 'low',
#    '048': 'low',
#    '064': 'high',
#    '100': 'high',
#    '121': 'high',
#    '122': 'high',
#    '142': 'high',
#    '158': 'high',
#    '183': 'high',
#    '211': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 22,
#   'stimIDs': ['022',
#    '031',
#    '058',
#    '066',
#    '102',
#    '124',
#    '140',
#    '168',
#    '176',
#    '208'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-022-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-031-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-058-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-066-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-102-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-124-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-140-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-168-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-176-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-208-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'022': 'low',
#    '031': 'low',
#    '058': 'high',
#    '066': 'high',
#    '102': 'high',
#    '124': 'high',
#    '140': 'high',
#    '168': 'high',
#    '176': 'high',
#    '208': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 23,
#   'stimIDs': ['008',
#    '038',
#    '073',
#    '092',
#    '111',
#    '146',
#    '147',
#    '195',
#    '197',
#    '229'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-008-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-038-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-073-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-092-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-111-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-146-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-147-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-195-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-197-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-229-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'008': 'low',
#    '038': 'low',
#    '073': 'high',
#    '092': 'high',
#    '111': 'high',
#    '146': 'high',
#    '147': 'high',
#    '195': 'high',
#    '197': 'high',
#    '229': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'partitionFamily': 1,
#   'splitNumber': 24,
#   'stimIDs': ['006',
#    '016',
#    '115',
#    '139',
#    '149',
#    '164',
#    '174',
#    '190',
#    '200',
#    '218'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-006-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-016-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-115-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-139-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-149-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-164-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-174-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-190-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-200-all.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-structures-bridge-218-all.png'],
#   'ntrials': 10,
#   'stimGroups': {'006': 'low',
#    '016': 'low',
#    '115': 'high',
#    '139': 'high',
#    '149': 'high',
#    '164': 'high',
#    '174': 'high',
#    '190': 'high',
#    '200': 'high',
#    '218': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_structures_bridge_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0}]

# %%
experiment_name
# Out:
# 'lax_drawing_dials_10'

# %%
# Clear metadata collection

really_run = False;

if really_run:
    db.drop_collection(experiment_name)

# %%
## now, iterate through each version and insert into mongo
## loop through list of records and insert each into collection
reallyRun = False
if reallyRun:
    for (i,j) in enumerate(metadata):
        coll.insert_one(j)
        print('Inserted version {} of stimDict.'.format(j['versionInd']))
        clear_output(wait=True)

else:
    print('Did not insert any new data.')
# Out:
# Inserted version 0 of stimDict.

# %%
list(coll.find())
# Out:
# [{'_id': ObjectId('617733fe32bed710461f583d'),
#   'partitionFamily': 0,
#   'splitNumber': 0,
#   'stimIDs': ['034',
#    '047',
#    '071',
#    '090',
#    '132',
#    '145',
#    '161',
#    '199',
#    '216',
#    '235'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-034.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-047.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-071.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-090.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-132.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-145.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-161.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-199.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-216.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-235.png'],
#   'ntrials': 10,
#   'stimGroups': {'034': 'low',
#    '047': 'low',
#    '071': 'high',
#    '090': 'high',
#    '132': 'high',
#    '145': 'high',
#    '161': 'high',
#    '199': 'high',
#    '216': 'high',
#    '235': 'high'},
#   'numGames': 1,
#   'games': ['7362-adc7124c-9221-4770-b2f3-5e9171973477'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733fe32bed710461f583e'),
#   'partitionFamily': 0,
#   'splitNumber': 1,
#   'stimIDs': ['004',
#    '046',
#    '056',
#    '070',
#    '094',
#    '113',
#    '143',
#    '166',
#    '171',
#    '228'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-004.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-046.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-056.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-070.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-094.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-113.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-143.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-166.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-171.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-228.png'],
#   'ntrials': 10,
#   'stimGroups': {'004': 'low',
#    '046': 'low',
#    '056': 'high',
#    '070': 'high',
#    '094': 'high',
#    '113': 'high',
#    '143': 'high',
#    '166': 'high',
#    '171': 'high',
#    '228': 'high'},
#   'numGames': 1,
#   'games': ['6323-60a2f3f0-7a0c-4d9a-9914-f8c7abd0772f'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733fe32bed710461f583f'),
#   'partitionFamily': 0,
#   'splitNumber': 2,
#   'stimIDs': ['009',
#    '030',
#    '091',
#    '111',
#    '123',
#    '126',
#    '154',
#    '175',
#    '208',
#    '243'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-009.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-030.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-091.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-111.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-123.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-126.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-154.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-175.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-208.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-243.png'],
#   'ntrials': 10,
#   'stimGroups': {'009': 'low',
#    '030': 'low',
#    '091': 'high',
#    '111': 'high',
#    '123': 'high',
#    '126': 'high',
#    '154': 'high',
#    '175': 'high',
#    '208': 'high',
#    '243': 'high'},
#   'numGames': 1,
#   'games': ['4029-c3cd761c-7ddf-4b0a-bba2-effa40413f8f'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733fe32bed710461f5840'),
#   'partitionFamily': 0,
#   'splitNumber': 3,
#   'stimIDs': ['015',
#    '038',
#    '084',
#    '122',
#    '124',
#    '138',
#    '147',
#    '148',
#    '172',
#    '237'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-015.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-038.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-084.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-122.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-124.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-138.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-147.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-148.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-172.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-237.png'],
#   'ntrials': 10,
#   'stimGroups': {'015': 'low',
#    '038': 'low',
#    '084': 'high',
#    '122': 'high',
#    '124': 'high',
#    '138': 'high',
#    '147': 'high',
#    '148': 'high',
#    '172': 'high',
#    '237': 'high'},
#   'numGames': 1,
#   'games': ['5221-cc4bd5a0-5f06-4296-aa41-9476dbe98027'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733fe32bed710461f5841'),
#   'partitionFamily': 0,
#   'splitNumber': 4,
#   'stimIDs': ['027',
#    '043',
#    '058',
#    '074',
#    '079',
#    '119',
#    '158',
#    '197',
#    '231',
#    '244'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-027.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-043.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-058.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-074.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-079.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-119.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-158.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-197.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-231.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-244.png'],
#   'ntrials': 10,
#   'stimGroups': {'027': 'low',
#    '043': 'low',
#    '058': 'high',
#    '074': 'high',
#    '079': 'high',
#    '119': 'high',
#    '158': 'high',
#    '197': 'high',
#    '231': 'high',
#    '244': 'high'},
#   'numGames': 1,
#   'games': ['3059-280584e5-e0be-4fec-924c-54167b8c3b65'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733fe32bed710461f5842'),
#   'partitionFamily': 0,
#   'splitNumber': 5,
#   'stimIDs': ['001',
#    '002',
#    '065',
#    '101',
#    '142',
#    '170',
#    '177',
#    '186',
#    '215',
#    '239'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-001.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-002.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-065.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-101.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-142.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-170.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-177.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-186.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-215.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-239.png'],
#   'ntrials': 10,
#   'stimGroups': {'001': 'low',
#    '002': 'low',
#    '065': 'high',
#    '101': 'high',
#    '142': 'high',
#    '170': 'high',
#    '177': 'high',
#    '186': 'high',
#    '215': 'high',
#    '239': 'high'},
#   'numGames': 1,
#   'games': ['8286-2c2d1b35-2f06-4239-bb8f-d4a0fb2bba89'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733fe32bed710461f5843'),
#   'partitionFamily': 0,
#   'splitNumber': 6,
#   'stimIDs': ['028',
#    '035',
#    '061',
#    '136',
#    '157',
#    '160',
#    '173',
#    '203',
#    '204',
#    '246'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-028.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-035.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-061.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-136.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-157.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-160.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-173.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-203.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-204.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-246.png'],
#   'ntrials': 10,
#   'stimGroups': {'028': 'low',
#    '035': 'low',
#    '061': 'high',
#    '136': 'high',
#    '157': 'high',
#    '160': 'high',
#    '173': 'high',
#    '203': 'high',
#    '204': 'high',
#    '246': 'high'},
#   'numGames': 1,
#   'games': ['1592-2f32f96e-f55d-4de1-a93f-08b827b4da5f'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5844'),
#   'partitionFamily': 0,
#   'splitNumber': 7,
#   'stimIDs': ['016',
#    '020',
#    '072',
#    '108',
#    '134',
#    '150',
#    '151',
#    '169',
#    '180',
#    '232'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-016.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-020.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-072.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-108.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-134.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-150.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-151.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-169.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-180.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-232.png'],
#   'ntrials': 10,
#   'stimGroups': {'016': 'low',
#    '020': 'low',
#    '072': 'high',
#    '108': 'high',
#    '134': 'high',
#    '150': 'high',
#    '151': 'high',
#    '169': 'high',
#    '180': 'high',
#    '232': 'high'},
#   'numGames': 1,
#   'games': ['9561-ac7cb280-b73e-4ece-9641-f80af61f108e'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5845'),
#   'partitionFamily': 0,
#   'splitNumber': 8,
#   'stimIDs': ['023',
#    '031',
#    '057',
#    '097',
#    '100',
#    '135',
#    '137',
#    '202',
#    '217',
#    '234'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-023.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-031.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-057.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-097.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-100.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-135.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-137.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-202.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-217.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-234.png'],
#   'ntrials': 10,
#   'stimGroups': {'023': 'low',
#    '031': 'low',
#    '057': 'high',
#    '097': 'high',
#    '100': 'high',
#    '135': 'high',
#    '137': 'high',
#    '202': 'high',
#    '217': 'high',
#    '234': 'high'},
#   'numGames': 1,
#   'games': ['5958-3d5d8b13-37b7-42c1-9d40-2521eaa1d112'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5846'),
#   'partitionFamily': 0,
#   'splitNumber': 9,
#   'stimIDs': ['014',
#    '042',
#    '053',
#    '078',
#    '104',
#    '128',
#    '141',
#    '149',
#    '211',
#    '242'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-014.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-042.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-053.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-078.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-104.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-128.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-141.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-149.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-211.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-242.png'],
#   'ntrials': 10,
#   'stimGroups': {'014': 'low',
#    '042': 'low',
#    '053': 'high',
#    '078': 'high',
#    '104': 'high',
#    '128': 'high',
#    '141': 'high',
#    '149': 'high',
#    '211': 'high',
#    '242': 'high'},
#   'numGames': 1,
#   'games': ['1945-d379ed72-1c7d-425b-98ad-cf5c37a121e0'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5847'),
#   'partitionFamily': 0,
#   'splitNumber': 10,
#   'stimIDs': ['025',
#    '041',
#    '052',
#    '076',
#    '159',
#    '165',
#    '174',
#    '205',
#    '218',
#    '226'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-025.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-041.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-052.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-076.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-159.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-165.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-174.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-205.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-218.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-226.png'],
#   'ntrials': 10,
#   'stimGroups': {'025': 'low',
#    '041': 'low',
#    '052': 'high',
#    '076': 'high',
#    '159': 'high',
#    '165': 'high',
#    '174': 'high',
#    '205': 'high',
#    '218': 'high',
#    '226': 'high'},
#   'numGames': 1,
#   'games': ['9967-796dc646-d81b-4582-9025-0b4ec6d580c5'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5848'),
#   'partitionFamily': 0,
#   'splitNumber': 11,
#   'stimIDs': ['008',
#    '039',
#    '066',
#    '080',
#    '081',
#    '110',
#    '195',
#    '200',
#    '201',
#    '225'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-008.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-039.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-066.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-080.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-081.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-110.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-195.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-200.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-201.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-225.png'],
#   'ntrials': 10,
#   'stimGroups': {'008': 'low',
#    '039': 'low',
#    '066': 'high',
#    '080': 'high',
#    '081': 'high',
#    '110': 'high',
#    '195': 'high',
#    '200': 'high',
#    '201': 'high',
#    '225': 'high'},
#   'numGames': 1,
#   'games': ['6496-d66451ac-f672-4478-bf70-ff9a209e44b1'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5849'),
#   'partitionFamily': 0,
#   'splitNumber': 12,
#   'stimIDs': ['029',
#    '037',
#    '073',
#    '083',
#    '125',
#    '127',
#    '193',
#    '212',
#    '222',
#    '230'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-029.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-037.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-073.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-083.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-125.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-127.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-193.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-212.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-222.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-230.png'],
#   'ntrials': 10,
#   'stimGroups': {'029': 'low',
#    '037': 'low',
#    '073': 'high',
#    '083': 'high',
#    '125': 'high',
#    '127': 'high',
#    '193': 'high',
#    '212': 'high',
#    '222': 'high',
#    '230': 'high'},
#   'numGames': 1,
#   'games': ['2910-134af566-c52f-442a-b147-be19767216ca'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f584a'),
#   'partitionFamily': 0,
#   'splitNumber': 13,
#   'stimIDs': ['005',
#    '012',
#    '051',
#    '063',
#    '107',
#    '109',
#    '118',
#    '146',
#    '163',
#    '240'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-005.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-012.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-051.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-063.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-107.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-109.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-118.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-146.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-163.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-240.png'],
#   'ntrials': 10,
#   'stimGroups': {'005': 'low',
#    '012': 'low',
#    '051': 'high',
#    '063': 'high',
#    '107': 'high',
#    '109': 'high',
#    '118': 'high',
#    '146': 'high',
#    '163': 'high',
#    '240': 'high'},
#   'numGames': 1,
#   'games': ['9638-5dc505bd-46d1-4ec4-a983-d19f592098e1'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f584b'),
#   'partitionFamily': 0,
#   'splitNumber': 14,
#   'stimIDs': ['000',
#    '019',
#    '077',
#    '085',
#    '093',
#    '187',
#    '191',
#    '198',
#    '206',
#    '229'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-000.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-019.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-077.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-085.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-093.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-187.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-191.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-198.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-206.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-229.png'],
#   'ntrials': 10,
#   'stimGroups': {'000': 'low',
#    '019': 'low',
#    '077': 'high',
#    '085': 'high',
#    '093': 'high',
#    '187': 'high',
#    '191': 'high',
#    '198': 'high',
#    '206': 'high',
#    '229': 'high'},
#   'numGames': 1,
#   'games': ['6891-bf110120-3dfb-4dd7-a15b-02cb360dbc50'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f584c'),
#   'partitionFamily': 0,
#   'splitNumber': 15,
#   'stimIDs': ['007',
#    '021',
#    '082',
#    '086',
#    '102',
#    '129',
#    '179',
#    '214',
#    '219',
#    '236'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-007.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-021.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-082.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-086.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-102.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-129.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-179.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-214.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-219.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-236.png'],
#   'ntrials': 10,
#   'stimGroups': {'007': 'low',
#    '021': 'low',
#    '082': 'high',
#    '086': 'high',
#    '102': 'high',
#    '129': 'high',
#    '179': 'high',
#    '214': 'high',
#    '219': 'high',
#    '236': 'high'},
#   'numGames': 1,
#   'games': ['0446-2964abb8-5f9a-4136-a59b-874d392f08ec'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f584d'),
#   'partitionFamily': 0,
#   'splitNumber': 16,
#   'stimIDs': ['010',
#    '022',
#    '089',
#    '099',
#    '153',
#    '183',
#    '213',
#    '241',
#    '245',
#    '249'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-010.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-022.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-089.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-099.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-153.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-183.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-213.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-241.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-245.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-249.png'],
#   'ntrials': 10,
#   'stimGroups': {'010': 'low',
#    '022': 'low',
#    '089': 'high',
#    '099': 'high',
#    '153': 'high',
#    '183': 'high',
#    '213': 'high',
#    '241': 'high',
#    '245': 'high',
#    '249': 'high'},
#   'numGames': 1,
#   'games': ['2659-8ac00c2f-9fa2-423e-b991-8d86edafcb78'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f584e'),
#   'partitionFamily': 0,
#   'splitNumber': 17,
#   'stimIDs': ['011',
#    '013',
#    '068',
#    '156',
#    '164',
#    '188',
#    '207',
#    '210',
#    '220',
#    '223'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-011.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-013.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-068.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-156.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-164.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-188.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-207.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-210.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-220.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-223.png'],
#   'ntrials': 10,
#   'stimGroups': {'011': 'low',
#    '013': 'low',
#    '068': 'high',
#    '156': 'high',
#    '164': 'high',
#    '188': 'high',
#    '207': 'high',
#    '210': 'high',
#    '220': 'high',
#    '223': 'high'},
#   'numGames': 1,
#   'games': ['7930-2e4c9cd0-76f3-4c79-9054-664c7f8ddf16'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f584f'),
#   'partitionFamily': 0,
#   'splitNumber': 18,
#   'stimIDs': ['036',
#    '040',
#    '069',
#    '096',
#    '098',
#    '116',
#    '144',
#    '167',
#    '189',
#    '209'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-036.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-040.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-069.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-096.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-098.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-116.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-144.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-167.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-189.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-209.png'],
#   'ntrials': 10,
#   'stimGroups': {'036': 'low',
#    '040': 'low',
#    '069': 'high',
#    '096': 'high',
#    '098': 'high',
#    '116': 'high',
#    '144': 'high',
#    '167': 'high',
#    '189': 'high',
#    '209': 'high'},
#   'numGames': 1,
#   'games': ['7272-a04c0eb3-6b9a-4f79-bcdf-b088c32f4dec'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5850'),
#   'partitionFamily': 0,
#   'splitNumber': 19,
#   'stimIDs': ['006',
#    '044',
#    '059',
#    '064',
#    '075',
#    '130',
#    '131',
#    '140',
#    '184',
#    '196'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-006.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-044.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-059.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-064.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-075.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-130.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-131.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-140.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-184.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-196.png'],
#   'ntrials': 10,
#   'stimGroups': {'006': 'low',
#    '044': 'low',
#    '059': 'high',
#    '064': 'high',
#    '075': 'high',
#    '130': 'high',
#    '131': 'high',
#    '140': 'high',
#    '184': 'high',
#    '196': 'high'},
#   'numGames': 1,
#   'games': ['5473-845f4505-709f-459b-b296-ec0249f9f2e9'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5851'),
#   'partitionFamily': 0,
#   'splitNumber': 20,
#   'stimIDs': ['003',
#    '032',
#    '050',
#    '088',
#    '105',
#    '114',
#    '121',
#    '181',
#    '194',
#    '247'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-003.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-032.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-050.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-088.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-105.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-114.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-121.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-181.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-194.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-247.png'],
#   'ntrials': 10,
#   'stimGroups': {'003': 'low',
#    '032': 'low',
#    '050': 'high',
#    '088': 'high',
#    '105': 'high',
#    '114': 'high',
#    '121': 'high',
#    '181': 'high',
#    '194': 'high',
#    '247': 'high'},
#   'numGames': 1,
#   'games': ['1693-3ca5a28b-4f87-4132-a9b1-5e223bc73db9'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5852'),
#   'partitionFamily': 0,
#   'splitNumber': 21,
#   'stimIDs': ['024',
#    '026',
#    '055',
#    '120',
#    '139',
#    '152',
#    '176',
#    '185',
#    '227',
#    '233'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-024.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-026.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-055.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-120.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-139.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-152.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-176.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-185.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-227.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-233.png'],
#   'ntrials': 10,
#   'stimGroups': {'024': 'low',
#    '026': 'low',
#    '055': 'high',
#    '120': 'high',
#    '139': 'high',
#    '152': 'high',
#    '176': 'high',
#    '185': 'high',
#    '227': 'high',
#    '233': 'high'},
#   'numGames': 1,
#   'games': ['2614-6879d30a-82dd-400a-999c-4f52550bac92'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5853'),
#   'partitionFamily': 0,
#   'splitNumber': 22,
#   'stimIDs': ['017',
#    '049',
#    '054',
#    '060',
#    '087',
#    '092',
#    '095',
#    '162',
#    '178',
#    '182'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-017.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-049.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-054.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-060.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-087.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-092.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-095.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-162.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-178.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-182.png'],
#   'ntrials': 10,
#   'stimGroups': {'017': 'low',
#    '049': 'low',
#    '054': 'high',
#    '060': 'high',
#    '087': 'high',
#    '092': 'high',
#    '095': 'high',
#    '162': 'high',
#    '178': 'high',
#    '182': 'high'},
#   'numGames': 1,
#   'games': ['1739-6f15b01a-de5d-4537-a9dc-d6b9ec86e0cb'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5854'),
#   'partitionFamily': 0,
#   'splitNumber': 23,
#   'stimIDs': ['045',
#    '048',
#    '103',
#    '106',
#    '112',
#    '117',
#    '133',
#    '168',
#    '192',
#    '238'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-045.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-048.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-103.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-106.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-112.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-117.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-133.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-168.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-192.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-238.png'],
#   'ntrials': 10,
#   'stimGroups': {'045': 'low',
#    '048': 'low',
#    '103': 'high',
#    '106': 'high',
#    '112': 'high',
#    '117': 'high',
#    '133': 'high',
#    '168': 'high',
#    '192': 'high',
#    '238': 'high'},
#   'numGames': 1,
#   'games': ['1028-a807c74a-442c-49a2-8bcc-8a0de2c6d51f'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5855'),
#   'partitionFamily': 0,
#   'splitNumber': 24,
#   'stimIDs': ['018',
#    '033',
#    '062',
#    '067',
#    '115',
#    '155',
#    '190',
#    '221',
#    '224',
#    '248'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-018.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-033.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-062.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-067.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-115.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-155.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-190.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-221.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-224.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-248.png'],
#   'ntrials': 10,
#   'stimGroups': {'018': 'low',
#    '033': 'low',
#    '062': 'high',
#    '067': 'high',
#    '115': 'high',
#    '155': 'high',
#    '190': 'high',
#    '221': 'high',
#    '224': 'high',
#    '248': 'high'},
#   'numGames': 1,
#   'games': ['6328-74a296d4-b86a-4e56-855a-f54cd3761ab5'],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5856'),
#   'partitionFamily': 1,
#   'splitNumber': 0,
#   'stimIDs': ['039',
#    '041',
#    '052',
#    '059',
#    '099',
#    '145',
#    '194',
#    '196',
#    '198',
#    '244'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-039.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-041.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-052.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-059.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-099.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-145.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-194.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-196.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-198.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-244.png'],
#   'ntrials': 10,
#   'stimGroups': {'039': 'low',
#    '041': 'low',
#    '052': 'high',
#    '059': 'high',
#    '099': 'high',
#    '145': 'high',
#    '194': 'high',
#    '196': 'high',
#    '198': 'high',
#    '244': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5857'),
#   'partitionFamily': 1,
#   'splitNumber': 1,
#   'stimIDs': ['004',
#    '005',
#    '083',
#    '097',
#    '130',
#    '169',
#    '181',
#    '212',
#    '225',
#    '234'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-004.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-005.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-083.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-097.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-130.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-169.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-181.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-212.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-225.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-234.png'],
#   'ntrials': 10,
#   'stimGroups': {'004': 'low',
#    '005': 'low',
#    '083': 'high',
#    '097': 'high',
#    '130': 'high',
#    '169': 'high',
#    '181': 'high',
#    '212': 'high',
#    '225': 'high',
#    '234': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5858'),
#   'partitionFamily': 1,
#   'splitNumber': 2,
#   'stimIDs': ['025',
#    '043',
#    '088',
#    '091',
#    '108',
#    '132',
#    '144',
#    '189',
#    '223',
#    '226'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-025.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-043.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-088.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-091.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-108.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-132.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-144.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-189.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-223.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-226.png'],
#   'ntrials': 10,
#   'stimGroups': {'025': 'low',
#    '043': 'low',
#    '088': 'high',
#    '091': 'high',
#    '108': 'high',
#    '132': 'high',
#    '144': 'high',
#    '189': 'high',
#    '223': 'high',
#    '226': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5859'),
#   'partitionFamily': 1,
#   'splitNumber': 3,
#   'stimIDs': ['036',
#    '037',
#    '068',
#    '087',
#    '098',
#    '107',
#    '188',
#    '232',
#    '240',
#    '243'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-036.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-037.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-068.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-087.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-098.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-107.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-188.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-232.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-240.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-243.png'],
#   'ntrials': 10,
#   'stimGroups': {'036': 'low',
#    '037': 'low',
#    '068': 'high',
#    '087': 'high',
#    '098': 'high',
#    '107': 'high',
#    '188': 'high',
#    '232': 'high',
#    '240': 'high',
#    '243': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f585a'),
#   'partitionFamily': 1,
#   'splitNumber': 4,
#   'stimIDs': ['045',
#    '046',
#    '051',
#    '071',
#    '078',
#    '086',
#    '094',
#    '096',
#    '187',
#    '214'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-045.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-046.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-051.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-071.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-078.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-086.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-094.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-096.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-187.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-214.png'],
#   'ntrials': 10,
#   'stimGroups': {'045': 'low',
#    '046': 'low',
#    '051': 'high',
#    '071': 'high',
#    '078': 'high',
#    '086': 'high',
#    '094': 'high',
#    '096': 'high',
#    '187': 'high',
#    '214': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f585b'),
#   'partitionFamily': 1,
#   'splitNumber': 5,
#   'stimIDs': ['029',
#    '044',
#    '081',
#    '114',
#    '116',
#    '143',
#    '184',
#    '205',
#    '235',
#    '242'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-029.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-044.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-081.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-114.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-116.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-143.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-184.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-205.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-235.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-242.png'],
#   'ntrials': 10,
#   'stimGroups': {'029': 'low',
#    '044': 'low',
#    '081': 'high',
#    '114': 'high',
#    '116': 'high',
#    '143': 'high',
#    '184': 'high',
#    '205': 'high',
#    '235': 'high',
#    '242': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f585c'),
#   'partitionFamily': 1,
#   'splitNumber': 6,
#   'stimIDs': ['019',
#    '047',
#    '067',
#    '070',
#    '135',
#    '138',
#    '148',
#    '155',
#    '239',
#    '246'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-019.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-047.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-067.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-070.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-135.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-138.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-148.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-155.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-239.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-246.png'],
#   'ntrials': 10,
#   'stimGroups': {'019': 'low',
#    '047': 'low',
#    '067': 'high',
#    '070': 'high',
#    '135': 'high',
#    '138': 'high',
#    '148': 'high',
#    '155': 'high',
#    '239': 'high',
#    '246': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f585d'),
#   'partitionFamily': 1,
#   'splitNumber': 7,
# ...
#    '030',
#    '063',
#    '072',
#    '074',
#    '075',
#    '105',
#    '123',
#    '202',
#    '236'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-007.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-030.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-063.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-072.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-074.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-075.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-105.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-123.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-202.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-236.png'],
#   'ntrials': 10,
#   'stimGroups': {'007': 'low',
#    '030': 'low',
#    '063': 'high',
#    '072': 'high',
#    '074': 'high',
#    '075': 'high',
#    '105': 'high',
#    '123': 'high',
#    '202': 'high',
#    '236': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5865'),
#   'partitionFamily': 1,
#   'splitNumber': 15,
#   'stimIDs': ['009',
#    '028',
#    '057',
#    '077',
#    '090',
#    '159',
#    '175',
#    '178',
#    '222',
#    '224'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-009.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-028.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-057.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-077.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-090.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-159.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-175.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-178.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-222.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-224.png'],
#   'ntrials': 10,
#   'stimGroups': {'009': 'low',
#    '028': 'low',
#    '057': 'high',
#    '077': 'high',
#    '090': 'high',
#    '159': 'high',
#    '175': 'high',
#    '178': 'high',
#    '222': 'high',
#    '224': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5866'),
#   'partitionFamily': 1,
#   'splitNumber': 16,
#   'stimIDs': ['010',
#    '026',
#    '089',
#    '109',
#    '110',
#    '154',
#    '156',
#    '199',
#    '230',
#    '248'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-010.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-026.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-089.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-109.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-110.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-154.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-156.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-199.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-230.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-248.png'],
#   'ntrials': 10,
#   'stimGroups': {'010': 'low',
#    '026': 'low',
#    '089': 'high',
#    '109': 'high',
#    '110': 'high',
#    '154': 'high',
#    '156': 'high',
#    '199': 'high',
#    '230': 'high',
#    '248': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('617733ff32bed710461f5867'),
#   'partitionFamily': 1,
#   'splitNumber': 17,
#   'stimIDs': ['001',
#    '032',
#    '053',
#    '080',
#    '085',
#    '118',
#    '128',
#    '171',
#    '210',
#    '215'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-001.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-032.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-053.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-080.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-085.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-118.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-128.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-171.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-210.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-215.png'],
#   'ntrials': 10,
#   'stimGroups': {'001': 'low',
#    '032': 'low',
#    '053': 'high',
#    '080': 'high',
#    '085': 'high',
#    '118': 'high',
#    '128': 'high',
#    '171': 'high',
#    '210': 'high',
#    '215': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('6177340032bed710461f5868'),
#   'partitionFamily': 1,
#   'splitNumber': 18,
#   'stimIDs': ['013',
#    '049',
#    '103',
#    '104',
#    '127',
#    '161',
#    '185',
#    '191',
#    '204',
#    '247'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-013.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-049.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-103.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-104.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-127.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-161.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-185.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-191.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-204.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-247.png'],
#   'ntrials': 10,
#   'stimGroups': {'013': 'low',
#    '049': 'low',
#    '103': 'high',
#    '104': 'high',
#    '127': 'high',
#    '161': 'high',
#    '185': 'high',
#    '191': 'high',
#    '204': 'high',
#    '247': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('6177340032bed710461f5869'),
#   'partitionFamily': 1,
#   'splitNumber': 19,
#   'stimIDs': ['003',
#    '011',
#    '101',
#    '131',
#    '153',
#    '172',
#    '173',
#    '193',
#    '220',
#    '228'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-003.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-011.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-101.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-131.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-153.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-172.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-173.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-193.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-220.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-228.png'],
#   'ntrials': 10,
#   'stimGroups': {'003': 'low',
#    '011': 'low',
#    '101': 'high',
#    '131': 'high',
#    '153': 'high',
#    '172': 'high',
#    '173': 'high',
#    '193': 'high',
#    '220': 'high',
#    '228': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('6177340032bed710461f586a'),
#   'partitionFamily': 1,
#   'splitNumber': 20,
#   'stimIDs': ['002',
#    '020',
#    '065',
#    '126',
#    '170',
#    '179',
#    '180',
#    '213',
#    '216',
#    '219'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-002.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-020.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-065.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-126.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-170.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-179.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-180.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-213.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-216.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-219.png'],
#   'ntrials': 10,
#   'stimGroups': {'002': 'low',
#    '020': 'low',
#    '065': 'high',
#    '126': 'high',
#    '170': 'high',
#    '179': 'high',
#    '180': 'high',
#    '213': 'high',
#    '216': 'high',
#    '219': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('6177340032bed710461f586b'),
#   'partitionFamily': 1,
#   'splitNumber': 21,
#   'stimIDs': ['015',
#    '048',
#    '064',
#    '100',
#    '121',
#    '122',
#    '142',
#    '158',
#    '183',
#    '211'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-015.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-048.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-064.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-100.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-121.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-122.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-142.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-158.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-183.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-211.png'],
#   'ntrials': 10,
#   'stimGroups': {'015': 'low',
#    '048': 'low',
#    '064': 'high',
#    '100': 'high',
#    '121': 'high',
#    '122': 'high',
#    '142': 'high',
#    '158': 'high',
#    '183': 'high',
#    '211': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('6177340032bed710461f586c'),
#   'partitionFamily': 1,
#   'splitNumber': 22,
#   'stimIDs': ['022',
#    '031',
#    '058',
#    '066',
#    '102',
#    '124',
#    '140',
#    '168',
#    '176',
#    '208'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-022.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-031.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-058.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-066.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-102.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-124.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-140.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-168.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-176.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-208.png'],
#   'ntrials': 10,
#   'stimGroups': {'022': 'low',
#    '031': 'low',
#    '058': 'high',
#    '066': 'high',
#    '102': 'high',
#    '124': 'high',
#    '140': 'high',
#    '168': 'high',
#    '176': 'high',
#    '208': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('6177340032bed710461f586d'),
#   'partitionFamily': 1,
#   'splitNumber': 23,
#   'stimIDs': ['008',
#    '038',
#    '073',
#    '092',
#    '111',
#    '146',
#    '147',
#    '195',
#    '197',
#    '229'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-008.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-038.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-073.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-092.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-111.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-146.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-147.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-195.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-197.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-229.png'],
#   'ntrials': 10,
#   'stimGroups': {'008': 'low',
#    '038': 'low',
#    '073': 'high',
#    '092': 'high',
#    '111': 'high',
#    '146': 'high',
#    '147': 'high',
#    '195': 'high',
#    '197': 'high',
#    '229': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0},
#  {'_id': ObjectId('6177340032bed710461f586e'),
#   'partitionFamily': 1,
#   'splitNumber': 24,
#   'stimIDs': ['006',
#    '016',
#    '115',
#    '139',
#    '149',
#    '164',
#    '174',
#    '190',
#    '200',
#    '218'],
#   'stimURLS': ['https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-006.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-016.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-115.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-139.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-149.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-164.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-174.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-190.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-200.png',
#    'https://lax-drawing-dials-all.s3.amazonaws.com/lax-drawing-dials-all-218.png'],
#   'ntrials': 10,
#   'stimGroups': {'006': 'low',
#    '016': 'low',
#    '115': 'high',
#    '139': 'high',
#    '149': 'high',
#    '164': 'high',
#    '174': 'high',
#    '190': 'high',
#    '200': 'high',
#    '218': 'high'},
#   'numGames': 0,
#   'games': [],
#   'experimentType': 'corpus_collection',
#   'experimentName': 'lax_drawing_dials_10',
#   's3_bucket_url': 'https://lax-drawing-dials-all.s3.amazonaws.com/',
#   'versionInd': 0}]

# %% [markdown]
# ## Test which versions have been run
#
# This grabs the dataframe created by data generator, to see which records need to be run more times.
#
# It wipes the metadata from mongo, and replaces it with individual records for each additional partition that needs to be run.

# %% [markdown]
# # TOP-UP BATCH
# ### REFRESH ALL DOMAINS BY RUNNING FROM HERE

# %% [markdown]
# #### Generate dataframe from data collection

# %%
subdomains = {
    'structures' :  ['bridge', 'castle', 'house', 'city'],
    'drawing' :  ['nuts-bolts','wheels','furniture','dials']
}

domains = list(subdomains.keys())


iteration_names = ['corpus_prolific_test','corpus_prolific_test_3']
experiment_template = "lax-{}-{}-corpus-{}-10"
condition = 'procedural'
expected_trials = 10

df_trial = pd.DataFrame()
df_all = pd.DataFrame()

db_data = conn['lax']

for domain in domains:
    col_name = 'lax_{}_corpus'.format(domain)
    coll_data = db_data[col_name]
    
    for subdomain in subdomains[domain]:
        
        # get all data for subdomain from db
        df_subdomain_all = pd.DataFrame(coll_data.find({"$and":[ {'iterationName' : { '$in': iteration_names }},
                                          {'experimentName': experiment_template.format(domain, subdomain, condition)},
                                         ]}))
        
        if len(df_subdomain_all) > 0:

            df_subdomain_all['domain'] = domain
            df_subdomain_all['subdomain'] = subdomain


            # get metadata
            df_subdomain_meta = df_subdomain_all[(df_subdomain_all.datatype == 'stim_metadata')]\
                                        [["gameID","partitionFamily","splitNumber","stimIDs", "stimURLS", "stimGroups",
                                          "numGames","experimentType","experimentName","versionInd"]]

            # get trial data
            df_subdomain_trial = df_subdomain_all[\
                      (df_subdomain_all.trial_type == 'stimuli-contextual-language-production') &
                      (df_subdomain_all.datatype == 'trial_end') &
                      (~pd.isna(df_subdomain_all.stimId))]\
                      [['datatype', 'iterationName', 'condition', 'domain', 'subdomain',
                        'config_name', 'gameID', 'shuffle', 'trialOrder', 'rt', 'workerID', 
                        'trial_type', 'trial_index', 'time_elapsed', 'internal_node_id',
                        'view_history', 'stimId', 'stimURL', 'responses']]

            # merge metadata into trial data

            # verify stim groups in metadata are correct
            dicts = list(df_subdomain_all[df_subdomain_all.datatype=='stim_metadata']['stimGroups'])
            stim_groups = reduce(lambda dict1, dict2: {**dict1, **dict2}, dicts)
            stim_groups['demo_stim'] = 'demo_stim'
            # assign stim groups from metadata
            df_subdomain_trial['stim_group'] = df_subdomain_trial['stimId'].apply(lambda stim: stim_groups[stim])
            df_subdomain_trial = df_subdomain_trial.merge(df_subdomain_meta, how='left', on='gameID')

            # append subdomain data to main dataframe
            df_trial = df_trial.append(df_subdomain_trial, ignore_index=True)
            
        else:
            print('no data for ' + domain + '.' + subdomain)

# %%
df_trial.loc[:, 'responses'] = df_trial.responses.apply(ast.literal_eval)

# %% [markdown]
# #### Mark completed datasets

# %%
# find full datasets
did_complete = df_trial[df_trial.stim_group != 'demo_stim'].groupby(['gameID']).count()['datatype'] == expected_trials
complete_dataset_gameIDs = list(did_complete[did_complete].index)

df_trial.loc[:,'complete_dataset'] = False
df_trial.loc[(df_trial.gameID.isin(complete_dataset_gameIDs)), 'complete_dataset'] = True

# assign correct trial number
df_trial.loc[:,'trial_num'] = df_trial.trial_index - min(df_trial.trial_index.unique()[1:]) + 1
# assign practice trials to trial_num = 0
df_trial.loc[df_trial.trial_num < 0,'trial_num'] = 0

df_trial['rt_mins'] = df_trial.rt/(60*1000)

# %% [markdown]
# #### Find ppts for whom no trials hit the 8 step limit

# %%
# TODO: find datasets with no trials with 8 steps
def get_responses(response):

    whats = [key for key in response.keys() if 'what' in key]
    wheres = [key for key in response.keys() if 'where' in key]

    what_responses = [response[what] for what in whats]
    where_responses = [response[where] for where in wheres]

    return (what_responses, where_responses)

df_trial.loc[:, 'response_lists'] = df_trial.responses.apply(get_responses)
df_trial.loc[:, 'whats'] = df_trial.response_lists.apply(lambda x:x[0])
df_trial.loc[:, 'wheres'] = df_trial.response_lists.apply(lambda x:x[1])
df_trial.loc[:, 'n_steps'] = df_trial.whats.apply(len)

# %%
# mark those that hit 8 step limit

hit_8_step_limit = df_trial.groupby('gameID').n_steps.unique().apply(max) == 8

df_trial.loc[:, 'ppt_hit_8_step_limit'] = (df_trial.iterationName == 'corpus_prolific_test') & \
                                        (df_trial.gameID.apply(lambda id: hit_8_step_limit[id]))

# %%
df_trial[(df_trial.stimId!='demo_stim') &(df_trial.complete_dataset) & (~df_trial.ppt_hit_8_step_limit)]\
    .groupby(['subdomain','stimId'])['responses'].count().value_counts()
# Out:
# 2     1580
# 3      314
# 4       54
# 5       39
# 11       6
# 6        2
# 12       2
# 14       2
# 7        1
# Name: responses, dtype: int64

# %%
# how many complete datasets?
df_trial[(df_trial.complete_dataset) & (df_trial.trial_num > 0) & (~df_trial.ppt_hit_8_step_limit)].groupby(['domain','subdomain'])['rt'].count()/expected_trials
# Out:
# domain      subdomain
# drawing     dials         52.0
#             furniture     53.0
#             nuts-bolts    51.0
#             wheels        51.0
# structures  bridge        58.0
#             castle        76.0
#             city          68.0
#             house         56.0
# Name: rt, dtype: float64

# %% [markdown]
# #### find how many of each partition/ split

# %%
# based on completeness and hitting 8 step limit (USED ONLY ONCE TO REMOVE DATA)
# I.e. get complete datasets that are not from 'corpus_prolific_test' and hit the 8 step limit
complete_counts = (df_trial[(df_trial.complete_dataset) & 
                            ~(df_trial.ppt_hit_8_step_limit)]\
                   .groupby(['subdomain','partitionFamily','splitNumber'])\
                   .count()/(expected_trials+1))['datatype'].reset_index()


# # based on completeness only (i.e. )
# complete_counts = (df_trial[df_trial.complete_dataset]\
#                    .groupby(['subdomain','partitionFamily','splitNumber'])\
#                    .count()/(expected_trials+1))['datatype'].reset_index()

# %%
complete_counts
# Out:
#     subdomain  partitionFamily  splitNumber  datatype
# 0      bridge              0.0          0.0       1.0
# 1      bridge              0.0          1.0       1.0
# 2      bridge              0.0          2.0       1.0
# 3      bridge              0.0          3.0       1.0
# 4      bridge              0.0          4.0       1.0
# ..        ...              ...          ...       ...
# 395    wheels              1.0         20.0       1.0
# 396    wheels              1.0         21.0       1.0
# 397    wheels              1.0         22.0       1.0
# 398    wheels              1.0         23.0       1.0
# 399    wheels              1.0         24.0       1.0
#
# [400 rows x 4 columns]

# %% [markdown]
# #### top-up incomplete splits by adding individual record for each into top-up stimuli collection

# %%
# add a record in extra_metadata for each additional time a split needs to be run

def create_extra_metadata(complete_counts, domain, subdomain, df, n_expected = 1):

    experiment_name = df['experiment_name'][0]
    s3_bucket_path = df['s3_bucket_path'][0]
    
    assert subdomain in experiment_name
    
    extra_metadata = []

    for f in range(0, n_families):
        for s in range(0, n_splits):

            split_count = complete_counts[(complete_counts.partitionFamily == f) &
                                          (complete_counts.splitNumber == s) & 
                                          (complete_counts.subdomain == subdomain)
                                         ].reset_index()

            if len(split_count) == 0:
                n_completed = 0
            else:
                n_completed = split_count.loc[0,'datatype']

            i = n_completed

            while i < n_expected:

                i = i + 1

                stimIDs = list(df.groupby('family_'+str(f)).get_group(s)['stim_id'].apply(lambda x: str(x).zfill(3)))
        #         print(stim_numbers)
                extra_metadata.append(
                    {
                        'partitionFamily': f,
                        'splitNumber': s,
                        'stimIDs': stimIDs,
                        'stimURLS': [s3_bucket_path + "lax-{}-{}-{}-{}.png".format(domain,
                                                                      subdomain,
                                                                      (stimID if domain=='structures' else 'all'),
                                                                      ('all' if domain=='structures' else stimID))\
                                    for stimID in stimIDs],
                        'ntrials': len(stimIDs),
                        'stimGroups': {n: df.groupby('family_'+str(f)).get_group(s).reset_index().loc[i,'group'] for i, n in enumerate(stimIDs)},
                        'numGames': 0,
                        'games': [],
                        'experimentType': 'corpus_collection',
                        'experimentName': experiment_name,
                        's3_bucket_url': s3_bucket_path,
                        'versionInd': versionInd,
                        'extra_metadata_index': i
                    })
            
    return extra_metadata

# %%
upload_to_mongo = False

if not(upload_to_mongo):
    print('NO DATA UPLOADED')

for domain in domains:
    for subdomain in subdomains[domain]:
        
        print(domain + ', ' + subdomain)
        
        df_stim = get_stim_df(domain, subdomain)
        df_stim = generate_splits(df_stim)
        
        extra_metadata = create_extra_metadata(complete_counts,
                                               domain, 
                                               subdomain,
                                               df_stim,
                                               n_expected = 1)
        
        stim_col_name = df_stim['experiment_name'][0]
        top_up_stim_col_name = stim_col_name + '_top_up'
        print(top_up_stim_col_name)
        
        if upload_to_mongo:
            
            db = conn['stimuli']
            coll = db[top_up_stim_col_name]
            
            db.drop_collection(top_up_stim_col_name)
            print('cleared stimuli/' + top_up_stim_col_name)
            
            for (i,j) in enumerate(extra_metadata):
                coll.insert_one(j)
#                 clear_output(wait=True)
            
            print(str(len(list(coll.find()))) + ' inserted into stimuli/' + top_up_stim_col_name)
            
        else:
            print(str(len(extra_metadata)) + ' records to upload')
        
        print('')
        # TODO insert into db
# Out:
# NO DATA UPLOADED
# structures, bridge
# lax_structures_bridge_10_top_up
# 0 records to upload
#
# structures, castle
# lax_structures_castle_10_top_up
# 0 records to upload
#
# structures, house
# lax_structures_house_10_top_up
# 0 records to upload
#
# structures, city
# lax_structures_city_10_top_up
# 0 records to upload
#
# drawing, nuts-bolts
# lax_drawing_nuts-bolts_10_top_up
# 0 records to upload
#
# drawing, wheels
# lax_drawing_wheels_10_top_up
# 0 records to upload
#
# drawing, furniture
# lax_drawing_furniture_10_top_up
# 0 records to upload
#
# drawing, dials
# lax_drawing_dials_10_top_up
# 0 records to upload

# %% [markdown]
# # TO HERE

# %%
df_trial[~df_trial.ppt_hit_8_step_limit].groupby(['subdomain','complete_dataset']).count()/11
# Out:
#                               datatype  iterationName  condition     domain  \
# subdomain  complete_dataset
# bridge     False              1.000000       1.000000   1.000000   1.000000
#            True               8.000000       8.000000   8.000000   8.000000
# castle     False              1.909091       1.909091   1.909091   1.909091
#            True              11.000000      11.000000  11.000000  11.000000
# city       False              1.272727       1.272727   1.272727   1.272727
#            True               7.000000       7.000000   7.000000   7.000000
# dials      False              1.181818       1.181818   1.181818   1.181818
#            True              11.000000      11.000000  11.000000  11.000000
# furniture  False              2.636364       2.636364   2.636364   2.636364
#            True              22.000000      22.000000  22.000000  22.000000
# house      False              1.545455       1.545455   1.545455   1.545455
#            True               4.000000       4.000000   4.000000   4.000000
# nuts-bolts True              24.000000      24.000000  24.000000  24.000000
# wheels     False              1.818182       1.818182   1.818182   1.818182
#            True              18.000000      18.000000  18.000000  18.000000
#
#                              config_name     gameID  shuffle  trialOrder  \
# subdomain  complete_dataset
# bridge     False                1.000000   1.000000      0.0         0.0
#            True                 8.000000   8.000000      0.0         0.0
# castle     False                1.909091   1.909091      0.0         0.0
#            True                11.000000  11.000000      0.0         0.0
# city       False                1.272727   1.272727      0.0         0.0
#            True                 7.000000   7.000000      0.0         0.0
# dials      False                1.181818   1.181818      0.0         0.0
#            True                11.000000  11.000000      0.0         0.0
# furniture  False                2.636364   2.636364      0.0         0.0
#            True                22.000000  22.000000      0.0         0.0
# house      False                1.545455   1.545455      0.0         0.0
#            True                 4.000000   4.000000      0.0         0.0
# nuts-bolts True                24.000000  24.000000      0.0         0.0
# wheels     False                1.818182   1.818182      0.0         0.0
#            True                18.000000  18.000000      0.0         0.0
#
#                                     rt   workerID  ...  experimentType  \
# subdomain  complete_dataset                        ...
# bridge     False              1.000000   1.000000  ...        1.000000
#            True               8.000000   8.000000  ...        8.000000
# castle     False              1.909091   1.909091  ...        1.909091
#            True              11.000000  11.000000  ...       11.000000
# city       False              1.272727   1.272727  ...        1.272727
#            True               7.000000   7.000000  ...        7.000000
# dials      False              1.181818   1.181818  ...        1.181818
#            True              11.000000  11.000000  ...       11.000000
# furniture  False              2.636364   2.636364  ...        2.636364
#            True              22.000000  22.000000  ...       22.000000
# house      False              1.545455   1.545455  ...        1.545455
#            True               4.000000   4.000000  ...        4.000000
# nuts-bolts True              24.000000  24.000000  ...       24.000000
# wheels     False              1.818182   1.818182  ...        1.818182
#            True              18.000000  18.000000  ...       18.000000
#
#                              experimentName  versionInd  trial_num    rt_mins  \
# subdomain  complete_dataset
# bridge     False                   1.000000    1.000000   1.000000   1.000000
#            True                    8.000000    8.000000   8.000000   8.000000
# castle     False                   1.909091    1.909091   1.909091   1.909091
#            True                   11.000000   11.000000  11.000000  11.000000
# city       False                   1.272727    1.272727   1.272727   1.272727
#            True                    7.000000    7.000000   7.000000   7.000000
# dials      False                   1.181818    1.181818   1.181818   1.181818
#            True                   11.000000   11.000000  11.000000  11.000000
# furniture  False                   2.636364    2.636364   2.636364   2.636364
#            True                   22.000000   22.000000  22.000000  22.000000
# house      False                   1.545455    1.545455   1.545455   1.545455
#            True                    4.000000    4.000000   4.000000   4.000000
# nuts-bolts True                   24.000000   24.000000  24.000000  24.000000
# wheels     False                   1.818182    1.818182   1.818182   1.818182
#            True                   18.000000   18.000000  18.000000  18.000000
#
#                              response_lists      whats     wheres    n_steps  \
# subdomain  complete_dataset
# bridge     False                   1.000000   1.000000   1.000000   1.000000
#            True                    8.000000   8.000000   8.000000   8.000000
# castle     False                   1.909091   1.909091   1.909091   1.909091
#            True                   11.000000  11.000000  11.000000  11.000000
# city       False                   1.272727   1.272727   1.272727   1.272727
#            True                    7.000000   7.000000   7.000000   7.000000
# dials      False                   1.181818   1.181818   1.181818   1.181818
#            True                   11.000000  11.000000  11.000000  11.000000
# furniture  False                   2.636364   2.636364   2.636364   2.636364
#            True                   22.000000  22.000000  22.000000  22.000000
# house      False                   1.545455   1.545455   1.545455   1.545455
#            True                    4.000000   4.000000   4.000000   4.000000
# nuts-bolts True                   24.000000  24.000000  24.000000  24.000000
# wheels     False                   1.818182   1.818182   1.818182   1.818182
#            True                   18.000000  18.000000  18.000000  18.000000
#
#                              ppt_hit_8_step_limit
# subdomain  complete_dataset
# bridge     False                         1.000000
#            True                          8.000000
# castle     False                         1.909091
#            True                         11.000000
# city       False                         1.272727
#            True                          7.000000
# dials      False                         1.181818
#            True                         11.000000
# furniture  False                         2.636364
#            True                         22.000000
# house      False                         1.545455
#            True                          4.000000
# nuts-bolts True                         24.000000
# wheels     False                         1.818182
#            True                         18.000000
#
# [15 rows x 35 columns]
